# %% [markdown]
# # This Code is for the models using variable tenure_level
#
# ### Output label: Malicious
#
# ### Input features:
# #### Numerical feature: score
# #### Nominal Categorical features: owner_name, alert_type, Function_Group
# #### Ordinal Categorical features: classification, tenure_level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# load csv into dataframe df
df_main = pd.read_csv('processed_alerts_obfuscated_v2.csv')

# %%
# see the original dataset
df_main.head()
# Out:
#   type_name alert_escalation_date  alert_id_fk insert_date  score   status  \
# 0        TP       3/26/2018 20:18    319529787   9/29/2017    180  cleared
# 1        TP       3/26/2018 20:18   1633242574   9/29/2017    172  cleared
# 2        TP       3/26/2018 20:18   1633242574   9/29/2017    172  cleared
# 3        TP       3/26/2018 20:18   1633242574   9/29/2017    172  cleared
# 4        TP       3/26/2018 20:18   1633242574   9/29/2017    172  cleared
#
#   resolution        owner_name malicious  employee_id  risk_factor  avg_score  \
# 0     closed  Senior_Analyst_1       yes   2313834724         1.80      100.0
# 1     closed  Senior_Analyst_1       yes  13152813815         1.72      100.0
# 2     closed  Senior_Analyst_1       yes  13152813815         1.72      100.0
# 3     closed  Senior_Analyst_1       yes  13152813815         1.72      100.0
# 4     closed  Senior_Analyst_1       yes  13152813815         1.72      100.0
#
#   classification    HRU                  indicators  \
# 0          TP/DE   None        App_1_Box_Aged_Files
# 1          TP/DE  HRU11        App_1_Box_Aged_Files
# 2          TP/DE  HRU11  App_4_Request_Volume_30day
# 3          TP/DE  HRU11  App_4_Request_Volume_90day
# 4          TP/DE  HRU11          App_14_Threshold_1
#
#                                      indicator_pairs alert_category  \
# 0                               App_1_Box_Aged_Files           Heat
# 1  App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 2  App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 3  App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 4  App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
#
#    alert_type grouping  indicator_heat_score
# 0  Daily_Heat    App_1                   3.0
# 1  Daily_Heat    App_1                   3.0
# 2  Daily_Heat    App_4                   4.0
# 3  Daily_Heat    App_4                   3.0
# 4  Daily_Heat   App_14                   3.0

# %%
# give unique id to "alert_id_fk + alert_escalation_date + insert date"
df_main['alert_id'] = df_main.groupby(['alert_escalation_date','alert_id_fk','insert_date']).ngroup()
df_main
# Out:
#        type_name alert_escalation_date  alert_id_fk insert_date  score  \
# 0             TP       3/26/2018 20:18    319529787   9/29/2017    180
# 1             TP       3/26/2018 20:18   1633242574   9/29/2017    172
# 2             TP       3/26/2018 20:18   1633242574   9/29/2017    172
# 3             TP       3/26/2018 20:18   1633242574   9/29/2017    172
# 4             TP       3/26/2018 20:18   1633242574   9/29/2017    172
# 5             TP       3/26/2018 20:18   1134030338   9/29/2017    873
# 6             TP       3/26/2018 20:18    815365159   9/29/2017    811
# 7             TP       3/26/2018 20:18    815365159   9/29/2017    811
# 8             TP       3/26/2018 20:18    815365159   9/29/2017    811
# 9             TP       3/26/2018 20:18    815365159   9/29/2017    811
# 10            TP       3/26/2018 20:18    815365159   9/29/2017    811
# 11            TP       3/26/2018 20:18   1393818439   9/29/2017    195
# 12            FP       2/20/2018 19:31    815374709   9/29/2017     10
# 13            FP       2/20/2018 19:30    454369237   9/29/2017     10
# 14            TP       3/26/2018 20:18    612023860   9/29/2017    200
# 15            TP       3/26/2018 20:18    625554667   9/29/2017    174
# 16            TP       3/26/2018 20:18    529949117   9/29/2017   1520
# 17            TP       3/26/2018 20:18    529949117   9/29/2017   1520
# 18            TP       3/26/2018 20:18    598455899   9/29/2017    360
# 19            FP       2/20/2018 17:51    598459403   9/29/2017     10
# 20            FP       2/20/2018 17:51    612034613   9/29/2017     10
# 21            FP       2/20/2018 17:51    625565657   9/29/2017     10
# 22            FP       2/20/2018 17:51    639051559   9/29/2017     10
# 23            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 24            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 25            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 26            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 27            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 28            TP       3/26/2018 20:18   1563573952   9/30/2017    220
# 29            TP       3/26/2018 20:18   1563573952   9/30/2017    220
# ...          ...                   ...          ...         ...    ...
# 127680        TP       2/28/2019 19:37    846988822   2/28/2019    243
# 127681        TP       2/28/2019 19:48   2189084026   2/28/2019    516
# 127682        TP       2/28/2019 19:48   2189084026   2/28/2019    516
# 127683        TP       2/28/2019 19:48   2189084026   2/28/2019    516
# 127684        TP       2/28/2019 19:48   2189084026   2/28/2019    516
# 127685        TP       2/28/2019 18:32    789716786   2/28/2019  23441
# 127686        TP       2/28/2019 18:32    789716786   2/28/2019  23441
# 127687        TP       2/28/2019 18:32    789716786   2/28/2019  23441
# 127688        TP       2/28/2019 18:21   1693014914   2/28/2019  11199
# 127689        TP       2/28/2019 18:21   1693014914   2/28/2019  11199
# 127690        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127691        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127692        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127693        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127694        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127695        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127696        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127697        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127698        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127699        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127700        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127701        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127702        TP       2/28/2019 18:18    467823823   2/28/2019   2000
# 127703        TP       2/28/2019 18:21   2189094018   2/28/2019     10
# 127704        TP       2/28/2019 19:48    527953400   2/28/2019    522
# 127705        TP       2/28/2019 19:48    527953400   2/28/2019    522
# 127706        TP       2/28/2019 19:48    527953400   2/28/2019    522
# 127707        TP       2/28/2019 19:48    527953400   2/28/2019    522
# 127708        TP       2/28/2019 19:35   2185231487   2/28/2019     10
# 127709        TP       2/28/2019 19:35    847000419   2/28/2019     10
#
#          status resolution        owner_name malicious  employee_id    ...     \
# 0       cleared     closed  Senior_Analyst_1       yes   2313834724    ...
# 1       cleared     closed  Senior_Analyst_1       yes  13152813815    ...
# 2       cleared     closed  Senior_Analyst_1       yes  13152813815    ...
# 3       cleared     closed  Senior_Analyst_1       yes  13152813815    ...
# 4       cleared     closed  Senior_Analyst_1       yes  13152813815    ...
# 5       cleared     closed  Senior_Analyst_1       yes  20533197492    ...
# 6       cleared     closed  Senior_Analyst_1       yes  20992423005    ...
# 7       cleared     closed  Senior_Analyst_1       yes  20992423005    ...
# 8       cleared     closed  Senior_Analyst_1       yes  20992423005    ...
# 9       cleared     closed  Senior_Analyst_1       yes  20992423005    ...
# 10      cleared     closed  Senior_Analyst_1       yes  20992423005    ...
# 11      cleared     closed  Senior_Analyst_1       yes   2313834724    ...
# 12      cleared     closed  Senior_Analyst_1        no  13732187617    ...
# 13      cleared     closed  Senior_Analyst_1        no  13732187617    ...
# 14      cleared     closed  Senior_Analyst_1       yes   9476086518    ...
# 15      cleared     closed  Senior_Analyst_1       yes   2313834724    ...
# 16      cleared     closed  Senior_Analyst_1       yes   1806090031    ...
# 17      cleared     closed  Senior_Analyst_1       yes   1806090031    ...
# 18      cleared     closed  Senior_Analyst_1       yes  16955391895    ...
# 19      cleared     closed  Senior_Analyst_1        no  21238056044    ...
# 20      cleared     closed  Senior_Analyst_1        no  21238056044    ...
# 21      cleared     closed  Senior_Analyst_1        no  21238056044    ...
# 22      cleared     closed  Senior_Analyst_1        no  21238056044    ...
# 23      cleared     closed  Senior_Analyst_1       yes  14917297624    ...
# 24      cleared     closed  Senior_Analyst_1       yes  14917297624    ...
# 25      cleared     closed  Senior_Analyst_1       yes  14917297624    ...
# 26      cleared     closed  Senior_Analyst_1       yes  14917297624    ...
# 27      cleared     closed  Senior_Analyst_1       yes  14917297624    ...
# 28      cleared     closed  Senior_Analyst_1       yes  17021981216    ...
# 29      cleared     closed  Senior_Analyst_1       yes  17021981216    ...
# ...         ...        ...               ...       ...          ...    ...
# 127680  cleared     closed         Analyst_1       yes  32064643741    ...
# 127681  cleared     closed         Analyst_6       yes   1543875646    ...
# 127682  cleared     closed         Analyst_6       yes   1543875646    ...
# 127683  cleared     closed         Analyst_6       yes   1543875646    ...
# 127684  cleared     closed         Analyst_6       yes   1543875646    ...
# 127685  cleared     closed         Analyst_4       yes  14812664119    ...
# 127686  cleared     closed         Analyst_4       yes  14812664119    ...
# 127687  cleared     closed         Analyst_4       yes  14812664119    ...
# 127688  cleared     closed         Analyst_4       yes   2313727843    ...
# 127689  cleared     closed         Analyst_4       yes   2313727843    ...
# 127690  cleared     closed         Analyst_1       yes  10719547234    ...
# 127691  cleared     closed         Analyst_1       yes  10719547234    ...
# 127692  cleared     closed         Analyst_1       yes  10719547234    ...
# 127693  cleared     closed         Analyst_1       yes  10719547234    ...
# 127694  cleared     closed         Analyst_1       yes  10719547234    ...
# 127695  cleared     closed         Analyst_1       yes  10719547234    ...
# 127696  cleared     closed         Analyst_1       yes  10719547234    ...
# 127697  cleared     closed         Analyst_4       yes  17112580659    ...
# 127698  cleared     closed         Analyst_4       yes  17112580659    ...
# 127699  cleared     closed         Analyst_4       yes  17112580659    ...
# 127700  cleared     closed         Analyst_4       yes  17112580659    ...
# 127701  cleared     closed         Analyst_4       yes  17112580659    ...
# 127702  cleared     closed         Analyst_4       yes  18282552322    ...
# 127703  cleared     closed         Analyst_1       yes  17666907117    ...
# 127704  cleared     closed         Analyst_6       yes   1543875646    ...
# 127705  cleared     closed         Analyst_6       yes   1543875646    ...
# 127706  cleared     closed         Analyst_6       yes   1543875646    ...
# 127707  cleared     closed         Analyst_6       yes   1543875646    ...
# 127708  cleared     closed         Analyst_1       yes  17952231743    ...
# 127709  cleared     closed         Analyst_1       yes  17952231743    ...
#
#         avg_score  classification    HRU  \
# 0           100.0           TP/DE   None
# 1           100.0           TP/DE  HRU11
# 2           100.0           TP/DE  HRU11
# 3           100.0           TP/DE  HRU11
# 4           100.0           TP/DE  HRU11
# 5           101.0           TP/DE   None
# 6           100.0           TP/DE  HRU11
# 7           100.0           TP/DE  HRU11
# 8           100.0           TP/DE  HRU11
# 9           100.0           TP/DE  HRU11
# 10          100.0           TP/DE  HRU11
# 11          100.0           TP/DE   None
# 12            NaN              FP  HRU11
# 13            NaN              FP  HRU11
# 14          100.0           TP/DE   None
# 15          100.0           TP/DE   None
# 16          167.0           TP/DE   None
# 17          167.0           TP/DE   None
# 18          114.0           TP/DE   None
# 19            NaN              FP   None
# 20            NaN              FP   None
# 21            NaN              FP   None
# 22            NaN              FP   None
# 23          262.0           TP/DE   None
# 24          262.0           TP/DE   None
# 25          262.0           TP/DE   None
# 26          262.0           TP/DE   None
# 27          262.0           TP/DE   None
# 28          100.0           TP/DE   None
# 29          100.0           TP/DE   None
# ...           ...             ...    ...
# 127680      100.0           TP/DE   None
# 127681       90.0           TP/DE   None
# 127682       90.0           TP/DE   None
# 127683       90.0           TP/DE   None
# 127684       90.0           TP/DE   None
# 127685      553.0           TP/DE   None
# 127686      553.0           TP/DE   None
# 127687      553.0           TP/DE   None
# 127688      256.0           TP/DE  HRU11
# 127689      256.0           TP/DE  HRU11
# 127690       90.0           TP/DE   None
# 127691       90.0           TP/DE   None
# 127692       90.0           TP/DE   None
# 127693       90.0           TP/DE   None
# 127694       90.0           TP/DE   None
# 127695       90.0           TP/DE   None
# 127696       90.0           TP/DE   None
# 127697      126.0           TP/DE  HRU18
# 127698      126.0           TP/DE  HRU18
# 127699      126.0           TP/DE  HRU18
# 127700      126.0           TP/DE  HRU18
# 127701      126.0           TP/DE  HRU18
# 127702       90.0           TP/DE   HRU2
# 127703        NaN           TP/DE  HRU11
# 127704       90.0           TP/DE   None
# 127705       90.0           TP/DE   None
# 127706       90.0           TP/DE   None
# 127707       90.0           TP/DE   None
# 127708        NaN           TP/DE   None
# 127709        NaN           TP/DE   None
#
#                                                indicators  \
# 0                                    App_1_Box_Aged_Files
# 1                                    App_1_Box_Aged_Files
# 2                              App_4_Request_Volume_30day
# 3                              App_4_Request_Volume_90day
# 4                                      App_14_Threshold_1
# 5                                    App_1_Box_Aged_Files
# 6                                Threshold_Blocked_Alerts
# 7                     Top_Users_That_Egressed_Files_To_CD
# 8                               App_2_Access_Volume_30day
# 9                                App_2_Access_Volume_7day
# 10                                     App_14_Threshold_1
# 11                                   App_1_Box_Aged_Files
# 12                        App_1_External_Email_Aged_Files
# 13                        App_1_External_Email_Aged_Files
# 14                                         App_3_To_Print
# 15                                   App_1_Box_Aged_Files
# 16                              App_2_Access_Volume_30day
# 17                               App_2_Access_Volume_7day
# 18                                         App_3_To_Print
# 19                            App_3_Critical_Egress_Email
# 20                            App_3_Critical_Egress_Email
# 21                            App_3_Critical_Egress_Email
# 22                            App_3_Critical_Egress_Email
# 23                               Threshold_Blocked_Alerts
# 24                 Email_Attachments_To_Competitor_Domain
# 25                                     App_14_Threshold_1
# 26                                          App_11_To_USB
# 27                   Top_Users_That_Egressed_Files_To_USB
# 28                               Threshold_Blocked_Alerts
# 29                 Email_Attachments_To_Competitor_Domain
# ...                                                   ...
# 127680  Threshold_Large_Number_of_Email_Attachments_To...
# 127681             Email_Attachments_To_Competitor_Domain
# 127682  Threshold_Large_Number_of_Email_Attachments_To...
# 127683            Top_Users_That_Egressed_Files_To_Non_GE
# 127684               Top_Users_That_Egressed_Files_To_USB
# 127685             Email_Attachments_To_Competitor_Domain
# 127686                                 Email_CAD_To_NonGE
# 127687                                      App_11_To_Box
# 127688             Email_Attachments_To_Competitor_Domain
# 127689                                 Email_CAD_To_NonGE
# 127690                           Threshold_Blocked_Alerts
# 127691                          App_2_Access_Volume_30day
# 127692                           App_2_Access_Volume_7day
# 127693                   App_2_Plus_Key_Tech_Over_30_Days
# 127694                    App_2_Plus_Key_Tech_Over_7_Days
# 127695            App_4_Article_Access-7_Day_Threshold>10
# 127696                        App_4_Marked_General_Access
# 127697                              App_25_Keywords_Email
# 127698                                 MIL_Keywords_Email
# 127699                                  Military_Keywords
# 127700             Email_Attachments_To_Competitor_Domain
# 127701  Threshold_Large_Number_of_Email_Attachments_To...
# 127702                           App_2_Access_Volume_7day
# 127703                        App_3_Critical_Egress_Email
# 127704             Email_Attachments_To_Competitor_Domain
# 127705  Threshold_Large_Number_of_Email_Attachments_To...
# 127706            Top_Users_That_Egressed_Files_To_Non_GE
# 127707               Top_Users_That_Egressed_Files_To_USB
# 127708                           App_3_To_Internet_upload
# 127709                           App_3_To_Internet_upload
#
#                                           indicator_pairs alert_category  \
# 0                                    App_1_Box_Aged_Files           Heat
# 1       App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 2       App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 3       App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 4       App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 5                                    App_1_Box_Aged_Files           Heat
# 6       Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 7       Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 8       Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 9       Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 10      Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 11                                   App_1_Box_Aged_Files           Heat
# 12                        App_1_External_Email_Aged_Files         Atomic
# 13                        App_1_External_Email_Aged_Files         Atomic
# 14                                         App_3_To_Print           Heat
# 15                                   App_1_Box_Aged_Files           Heat
# 16      App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 17      App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 18                                         App_3_To_Print           Heat
# 19                            App_3_Critical_Egress_Email         Atomic
# 20                            App_3_Critical_Egress_Email         Atomic
# 21                            App_3_Critical_Egress_Email         Atomic
# 22                            App_3_Critical_Egress_Email         Atomic
# 23      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 24      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 25      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 26      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 27      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 28      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 29      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# ...                                                   ...            ...
# 127680  App_2_Email/Email_Attachments_To_Competitor_Do...           Heat
# 127681  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127682  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127683  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127684  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127685  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127686  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127687  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127688  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127689  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127690  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127691  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127692  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127693  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127694  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127695  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127696  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127697  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127698  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127699  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127700  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127701  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127702                           App_2_Access_Volume_7day           Heat
# 127703                        App_3_Critical_Egress_Email         Atomic
# 127704  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127705  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127706  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127707  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127708                           App_3_To_Internet_upload         Atomic
# 127709                           App_3_To_Internet_upload         Atomic
#
#           alert_type           grouping indicator_heat_score  alert_id
# 0         Daily_Heat              App_1                  3.0     60095
# 1         Daily_Heat              App_1                  3.0     60164
# 2         Daily_Heat              App_4                  4.0     60164
# 3         Daily_Heat              App_4                  3.0     60164
# 4         Daily_Heat             App_14                  3.0     60164
# 5       Monthly_Heat              App_1                  3.0     60128
# 6       Monthly_Heat          Threshold                  0.0     60114
# 7       Monthly_Heat          Top_Users                  0.0     60114
# 8       Monthly_Heat              App_2                 40.0     60114
# 9       Monthly_Heat              App_2                 50.0     60114
# 10      Monthly_Heat             App_14                  3.0     60114
# 11        Daily_Heat              App_1                  3.0     60141
# 12            Atomic              App_1                  NaN     35163
# 13            Atomic              App_1                  NaN     34985
# 14        Daily_Heat              App_3                 20.0     60108
# 15        Daily_Heat              App_1                  3.0     60109
# 16      Monthly_Heat              App_2                 40.0     60102
# 17      Monthly_Heat              App_2                 50.0     60102
# 18        Daily_Heat              App_3                 20.0     60105
# 19            Atomic              App_3                  NaN     34109
# 20            Atomic              App_3                  NaN     34113
# 21            Atomic              App_3                  NaN     34115
# 22            Atomic              App_3                  NaN     34119
# 23       Weekly_Heat          Threshold                  0.0     60110
# 24       Weekly_Heat              Email                  3.0     60110
# 25       Weekly_Heat             App_14                  3.0     60110
# 26       Weekly_Heat             App_11                  2.0     60110
# 27       Weekly_Heat          Top_Users                  0.0     60110
# 28        Daily_Heat          Threshold                  0.0     60153
# 29        Daily_Heat              Email                  3.0     60153
# ...              ...                ...                  ...       ...
# 127680    Daily_Heat          Threshold                  0.0     38773
# 127681   Weekly_Heat              Email                  3.0     38776
# 127682   Weekly_Heat          Threshold                  0.0     38776
# 127683   Weekly_Heat          Top_Users                  0.0     38776
# 127684   Weekly_Heat          Top_Users                  0.0     38776
# 127685  Monthly_Heat              Email                  3.0     38769
# 127686  Monthly_Heat              Email                  4.0     38769
# 127687  Monthly_Heat             App_11                  1.0     38769
# 127688  Monthly_Heat              Email                  3.0     38767
# 127689  Monthly_Heat              Email                  4.0     38767
# 127690  Monthly_Heat          Threshold                  0.0     38766
# 127691  Monthly_Heat              App_2                 40.0     38766
# 127692  Monthly_Heat              App_2                 50.0     38766
# 127693  Monthly_Heat              App_2                  4.0     38766
# 127694  Monthly_Heat              App_2                  5.0     38766
# 127695  Monthly_Heat              App_4                  5.0     38766
# 127696  Monthly_Heat              App_4                  1.0     38766
# 127697  Monthly_Heat             App_25                 10.0     38770
# 127698  Monthly_Heat  Military_Keywords                 10.0     38770
# 127699  Monthly_Heat  Military_Keywords                  0.0     38770
# 127700  Monthly_Heat              Email                  3.0     38770
# 127701  Monthly_Heat          Threshold                  0.0     38770
# 127702  Monthly_Heat              App_2                 50.0     38764
# 127703        Atomic              App_3                  NaN     38768
# 127704   Weekly_Heat              Email                  3.0     38775
# 127705   Weekly_Heat          Threshold                  0.0     38775
# 127706   Weekly_Heat          Top_Users                  0.0     38775
# 127707   Weekly_Heat          Top_Users                  0.0     38775
# 127708        Atomic              App_3                  NaN     38772
# 127709        Atomic              App_3                  NaN     38771
#
# [127710 rows x 21 columns]

# %%
# drop duplicate by a column name
df=df_main.drop_duplicates(['alert_id'])
df
# Out:
#        type_name alert_escalation_date  alert_id_fk insert_date  score  \
# 0             TP       3/26/2018 20:18    319529787   9/29/2017    180
# 1             TP       3/26/2018 20:18   1633242574   9/29/2017    172
# 5             TP       3/26/2018 20:18   1134030338   9/29/2017    873
# 6             TP       3/26/2018 20:18    815365159   9/29/2017    811
# 11            TP       3/26/2018 20:18   1393818439   9/29/2017    195
# 12            FP       2/20/2018 19:31    815374709   9/29/2017     10
# 13            FP       2/20/2018 19:30    454369237   9/29/2017     10
# 14            TP       3/26/2018 20:18    612023860   9/29/2017    200
# 15            TP       3/26/2018 20:18    625554667   9/29/2017    174
# 16            TP       3/26/2018 20:18    529949117   9/29/2017   1520
# 18            TP       3/26/2018 20:18    598455899   9/29/2017    360
# 19            FP       2/20/2018 17:51    598459403   9/29/2017     10
# 20            FP       2/20/2018 17:51    612034613   9/29/2017     10
# 21            FP       2/20/2018 17:51    625565657   9/29/2017     10
# 22            FP       2/20/2018 17:51    639051559   9/29/2017     10
# 23            TP       3/26/2018 20:18    625572984   9/29/2017   1376
# 28            TP       3/26/2018 20:18   1563573952   9/30/2017    220
# 31            TP       3/26/2018 20:18   1634103350   9/30/2017   1095
# 37            TP       3/26/2018 20:18   1563583108   9/30/2017   1053
# 44            TP       3/26/2018 20:18    736737625   9/30/2017    200
# 45            TP       3/26/2018 20:18     48326430   9/30/2017    360
# 46            TP       3/26/2018 20:18   1477857936   9/30/2017    220
# 49            TP       3/26/2018 20:18   1694892925   9/30/2017   2008
# 55            TP       3/26/2018 20:18    547253590   9/30/2017    200
# 56            TP       3/26/2018 20:18   1205121754   9/30/2017   1370
# 61            FP       2/20/2018 19:31    267822692   9/30/2017     10
# 62            FP       2/20/2018 19:30    837779544   9/30/2017     10
# 63            TP       3/26/2018 20:18   1703739942   9/30/2017    851
# 68            TP       3/26/2018 20:18    606613241   9/30/2017    544
# 75            TP       3/26/2018 20:18    998869881   10/1/2017   1376
# ...          ...                   ...          ...         ...    ...
# 127641        TP       2/28/2019 13:33   1800657526   2/28/2019   1163
# 127644    TP/LOW       2/28/2019 13:24   1678807058   2/28/2019     10
# 127645    TP/LOW       2/28/2019 13:24   1542870914   2/28/2019     10
# 127646    TP/LOW       2/28/2019 13:24   1484478898   2/28/2019     10
# 127647    TP/LOW       2/28/2019 13:24   1625767674   2/28/2019     10
# 127648    TP/LOW       2/28/2019 13:24    991148708   2/28/2019     10
# 127649    TP/LOW       2/28/2019 13:24   1393990090   2/28/2019     10
# 127650    TP/LOW       2/28/2019 13:24   1907408262   2/28/2019     10
# 127651    TP/LOW       2/28/2019 13:24   1165835116   2/28/2019     10
# 127652    TP/LOW       2/28/2019 13:24   1800665745   2/28/2019     10
# 127653    TP/LOW       2/28/2019 13:24   1330742177   2/28/2019     10
# 127654    TP/LOW       2/28/2019 13:24   1678814721   2/28/2019     10
# 127655    TP/LOW       2/28/2019 13:59   1393996453   2/28/2019    740
# 127658        TP       2/28/2019 13:36    991153232   2/28/2019   1114
# 127663        TP       2/28/2019 14:15   1678822385   2/28/2019     10
# 127664    TP/LOW       2/28/2019 16:29   1394002816   2/28/2019    174
# 127669        TP       2/28/2019 15:39   1165845759   2/28/2019     10
# 127670        TP       2/28/2019 18:19    927384639   2/28/2019    723
# 127675        TP       2/28/2019 19:39   1885914205   2/28/2019    232
# 127678        TP       2/28/2019 19:37    846988822   2/28/2019    243
# 127681        TP       2/28/2019 19:48   2189084026   2/28/2019    516
# 127685        TP       2/28/2019 18:32    789716786   2/28/2019  23441
# 127688        TP       2/28/2019 18:21   1693014914   2/28/2019  11199
# 127690        TP       2/28/2019 18:19   1853732583   2/28/2019    766
# 127697        TP       2/28/2019 18:33    527950991   2/28/2019   1160
# 127702        TP       2/28/2019 18:18    467823823   2/28/2019   2000
# 127703        TP       2/28/2019 18:21   2189094018   2/28/2019     10
# 127704        TP       2/28/2019 19:48    527953400   2/28/2019    522
# 127708        TP       2/28/2019 19:35   2185231487   2/28/2019     10
# 127709        TP       2/28/2019 19:35    847000419   2/28/2019     10
#
#            status resolution        owner_name malicious  employee_id  \
# 0         cleared     closed  Senior_Analyst_1       yes   2313834724
# 1         cleared     closed  Senior_Analyst_1       yes  13152813815
# 5         cleared     closed  Senior_Analyst_1       yes  20533197492
# 6         cleared     closed  Senior_Analyst_1       yes  20992423005
# 11        cleared     closed  Senior_Analyst_1       yes   2313834724
# 12        cleared     closed  Senior_Analyst_1        no  13732187617
# 13        cleared     closed  Senior_Analyst_1        no  13732187617
# 14        cleared     closed  Senior_Analyst_1       yes   9476086518
# 15        cleared     closed  Senior_Analyst_1       yes   2313834724
# 16        cleared     closed  Senior_Analyst_1       yes   1806090031
# 18        cleared     closed  Senior_Analyst_1       yes  16955391895
# 19        cleared     closed  Senior_Analyst_1        no  21238056044
# 20        cleared     closed  Senior_Analyst_1        no  21238056044
# 21        cleared     closed  Senior_Analyst_1        no  21238056044
# 22        cleared     closed  Senior_Analyst_1        no  21238056044
# 23        cleared     closed  Senior_Analyst_1       yes  14917297624
# 28        cleared     closed  Senior_Analyst_1       yes  17021981216
# 31        cleared     closed  Senior_Analyst_1       yes  12410466738
# 37        cleared     closed  Senior_Analyst_1       yes  19331541121
# 44        cleared     closed  Senior_Analyst_1       yes   9476086518
# 45        cleared     closed  Senior_Analyst_1       yes  16955391895
# 46        cleared     closed  Senior_Analyst_1       yes  17021981216
# 49        cleared     closed  Senior_Analyst_1       yes  20603367907
# 55        cleared     closed  Senior_Analyst_1       yes   9476086518
# 56        cleared     closed  Senior_Analyst_1       yes  14917297624
# 61        cleared     closed  Senior_Analyst_1        no   5661237279
# 62        cleared     closed  Senior_Analyst_1        no   5661237279
# 63        cleared     closed  Senior_Analyst_1       yes  20992423005
# 68        cleared     closed  Senior_Analyst_1       yes  20994653327
# 75        cleared     closed  Senior_Analyst_1       yes  14917297624
# ...           ...        ...               ...       ...          ...
# 127641    cleared     closed         Analyst_4       yes    447642540
# 127644  confirmed     closed         Analyst_4       yes   5967617013
# 127645  confirmed     closed         Analyst_4       yes   5967617013
# 127646  confirmed     closed         Analyst_4       yes   5967617013
# 127647  confirmed     closed         Analyst_4       yes   5967617013
# 127648  confirmed     closed         Analyst_4       yes   5967617013
# 127649  confirmed     closed         Analyst_4       yes   5967617013
# 127650  confirmed     closed         Analyst_4       yes  20991899571
# 127651  confirmed     closed         Analyst_4       yes   5967617013
# 127652  confirmed     closed         Analyst_4       yes  20991899571
# 127653  confirmed     closed         Analyst_4       yes   5967617013
# 127654  confirmed     closed         Analyst_4       yes   5967617013
# 127655  confirmed     closed         Analyst_6       yes  46813231276
# 127658    cleared     closed         Analyst_4       yes  17112580659
# 127663    cleared     closed         Analyst_4       yes   1895149041
# 127664  confirmed     closed         Analyst_6        no  11636921589
# 127669    cleared     closed         Analyst_6       yes   6945283463
# 127670    cleared     closed         Analyst_1       yes  10719547234
# 127675    cleared     closed         Analyst_1       yes  18684782559
# 127678    cleared     closed         Analyst_1       yes  32064643741
# 127681    cleared     closed         Analyst_6       yes   1543875646
# 127685    cleared     closed         Analyst_4       yes  14812664119
# 127688    cleared     closed         Analyst_4       yes   2313727843
# 127690    cleared     closed         Analyst_1       yes  10719547234
# 127697    cleared     closed         Analyst_4       yes  17112580659
# 127702    cleared     closed         Analyst_4       yes  18282552322
# 127703    cleared     closed         Analyst_1       yes  17666907117
# 127704    cleared     closed         Analyst_6       yes   1543875646
# 127708    cleared     closed         Analyst_1       yes  17952231743
# 127709    cleared     closed         Analyst_1       yes  17952231743
#
#           ...     avg_score  classification    HRU  \
# 0         ...         100.0           TP/DE   None
# 1         ...         100.0           TP/DE  HRU11
# 5         ...         101.0           TP/DE   None
# 6         ...         100.0           TP/DE  HRU11
# 11        ...         100.0           TP/DE   None
# 12        ...           NaN              FP  HRU11
# 13        ...           NaN              FP  HRU11
# 14        ...         100.0           TP/DE   None
# 15        ...         100.0           TP/DE   None
# 16        ...         167.0           TP/DE   None
# 18        ...         114.0           TP/DE   None
# 19        ...           NaN              FP   None
# 20        ...           NaN              FP   None
# 21        ...           NaN              FP   None
# 22        ...           NaN              FP   None
# 23        ...         262.0           TP/DE   None
# 28        ...         100.0           TP/DE   None
# 31        ...         107.0           TP/DE   None
# 37        ...         100.0           TP/DE  HRU11
# 44        ...         100.0           TP/DE   None
# 45        ...         127.0           TP/DE   None
# 46        ...         100.0           TP/DE   None
# 49        ...         204.0           TP/DE   None
# 55        ...         100.0           TP/DE   None
# 56        ...         261.0           TP/DE   None
# 61        ...           NaN              FP  HRU13
# 62        ...           NaN              FP  HRU13
# 63        ...         100.0           TP/DE  HRU11
# 68        ...         103.0           TP/DE   None
# 75        ...         260.0           TP/DE   None
# ...       ...           ...             ...    ...
# 127641    ...         123.0           TP/DE   None
# 127644    ...           NaN          TP/LOW   HRU5
# 127645    ...           NaN          TP/LOW   HRU5
# 127646    ...           NaN          TP/LOW   HRU5
# 127647    ...           NaN          TP/LOW   HRU5
# 127648    ...           NaN          TP/LOW   HRU5
# 127649    ...           NaN          TP/LOW   HRU5
# 127650    ...           NaN          TP/LOW   HRU5
# 127651    ...           NaN          TP/LOW   HRU5
# 127652    ...           NaN          TP/LOW   HRU5
# 127653    ...           NaN          TP/LOW   HRU5
# 127654    ...           NaN          TP/LOW   HRU5
# 127655    ...          90.0          TP/LOW   None
# 127658    ...         125.0           TP/DE  HRU18
# 127663    ...           NaN           TP/DE   None
# 127664    ...         100.0          TP/LOW   None
# 127669    ...           NaN           TP/DE  HRU11
# 127670    ...          90.0           TP/DE   None
# 127675    ...         100.0           TP/DE   None
# 127678    ...         100.0           TP/DE   None
# 127681    ...          90.0           TP/DE   None
# 127685    ...         553.0           TP/DE   None
# 127688    ...         256.0           TP/DE  HRU11
# 127690    ...          90.0           TP/DE   None
# 127697    ...         126.0           TP/DE  HRU18
# 127702    ...          90.0           TP/DE   HRU2
# 127703    ...           NaN           TP/DE  HRU11
# 127704    ...          90.0           TP/DE   None
# 127708    ...           NaN           TP/DE   None
# 127709    ...           NaN           TP/DE   None
#
#                                     indicators  \
# 0                         App_1_Box_Aged_Files
# 1                         App_1_Box_Aged_Files
# 5                         App_1_Box_Aged_Files
# 6                     Threshold_Blocked_Alerts
# 11                        App_1_Box_Aged_Files
# 12             App_1_External_Email_Aged_Files
# 13             App_1_External_Email_Aged_Files
# 14                              App_3_To_Print
# 15                        App_1_Box_Aged_Files
# 16                   App_2_Access_Volume_30day
# 18                              App_3_To_Print
# 19                 App_3_Critical_Egress_Email
# 20                 App_3_Critical_Egress_Email
# 21                 App_3_Critical_Egress_Email
# 22                 App_3_Critical_Egress_Email
# 23                    Threshold_Blocked_Alerts
# 28                    Threshold_Blocked_Alerts
# 31                   App_2_Access_Volume_30day
# 37                    Threshold_Blocked_Alerts
# 44                              App_3_To_Print
# 45                              App_3_To_Print
# 46                    Threshold_Blocked_Alerts
# 49                          App_14_Threshold_1
# 55                              App_3_To_Print
# 56                    Threshold_Blocked_Alerts
# 61                    App_3_To_Internet_upload
# 62                    App_3_To_Internet_upload
# 63                    Threshold_Blocked_Alerts
# 68                   App_2_Access_Volume_30day
# 75                    Threshold_Blocked_Alerts
# ...                                        ...
# 127641                App_25_Military_Keywords
# 127644                               App_2_DWB
# 127645                               App_2_DWB
# 127646                               App_2_DWB
# 127647                               App_2_DWB
# 127648                               App_2_DWB
# 127649                               App_2_DWB
# 127650                               App_2_DWB
# 127651                               App_2_DWB
# 127652                               App_2_DWB
# 127653                               App_2_DWB
# 127654                               App_2_DWB
# 127655                Threshold_Blocked_Alerts
# 127658                   App_25_Keywords_Email
# 127663             App_3_Critical_Egress_Email
# 127664                Threshold_Blocked_Alerts
# 127669             App_3_Critical_Egress_Email
# 127670               App_2_Access_Volume_30day
# 127675                            App_3_To_USB
# 127678                             App_2_Email
# 127681  Email_Attachments_To_Competitor_Domain
# 127685  Email_Attachments_To_Competitor_Domain
# 127688  Email_Attachments_To_Competitor_Domain
# 127690                Threshold_Blocked_Alerts
# 127697                   App_25_Keywords_Email
# 127702                App_2_Access_Volume_7day
# 127703             App_3_Critical_Egress_Email
# 127704  Email_Attachments_To_Competitor_Domain
# 127708                App_3_To_Internet_upload
# 127709                App_3_To_Internet_upload
#
#                                           indicator_pairs alert_category  \
# 0                                    App_1_Box_Aged_Files           Heat
# 1       App_1_Box_Aged_Files/App_4_Request_Volume_30da...           Heat
# 5                                    App_1_Box_Aged_Files           Heat
# 6       Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 11                                   App_1_Box_Aged_Files           Heat
# 12                        App_1_External_Email_Aged_Files         Atomic
# 13                        App_1_External_Email_Aged_Files         Atomic
# 14                                         App_3_To_Print           Heat
# 15                                   App_1_Box_Aged_Files           Heat
# 16      App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 18                                         App_3_To_Print           Heat
# 19                            App_3_Critical_Egress_Email         Atomic
# 20                            App_3_Critical_Egress_Email         Atomic
# 21                            App_3_Critical_Egress_Email         Atomic
# 22                            App_3_Critical_Egress_Email         Atomic
# 23      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 28      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 31      App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 37      Threshold_Blocked_Alerts/App_2_Internet_Upload...           Heat
# 44                                         App_3_To_Print           Heat
# 45                                         App_3_To_Print           Heat
# 46      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 49      App_14_Threshold_1/App_8_Threshold_30day/App_8...           Heat
# 55                                         App_3_To_Print           Heat
# 56      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# 61                               App_3_To_Internet_upload         Atomic
# 62                               App_3_To_Internet_upload         Atomic
# 63      Threshold_Blocked_Alerts/Top_Users_That_Egress...           Heat
# 68      App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 75      Threshold_Blocked_Alerts/Email_Attachments_To_...           Heat
# ...                                                   ...            ...
# 127641  App_25_Military_Keywords/Threshold_Blocked_Ale...           Heat
# 127644                                          App_2_DWB         Atomic
# 127645                                          App_2_DWB         Atomic
# 127646                                          App_2_DWB         Atomic
# 127647                                          App_2_DWB         Atomic
# 127648                                          App_2_DWB         Atomic
# 127649                                          App_2_DWB         Atomic
# 127650                                          App_2_DWB         Atomic
# 127651                                          App_2_DWB         Atomic
# 127652                                          App_2_DWB         Atomic
# 127653                                          App_2_DWB         Atomic
# 127654                                          App_2_DWB         Atomic
# 127655  Threshold_Blocked_Alerts/Badge_Rejection_Disti...           Heat
# 127658  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127663                        App_3_Critical_Egress_Email         Atomic
# 127664  Threshold_Blocked_Alerts/Email_Zipped_to_exter...           Heat
# 127669                        App_3_Critical_Egress_Email         Atomic
# 127670  App_2_Access_Volume_30day/App_2_Access_Volume_...           Heat
# 127675  App_3_To_USB/App_11_To_USB/Top_Users_That_Egre...           Heat
# 127678  App_2_Email/Email_Attachments_To_Competitor_Do...           Heat
# 127681  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127685  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127688  Email_Attachments_To_Competitor_Domain/Email_C...           Heat
# 127690  Threshold_Blocked_Alerts/App_2_Access_Volume_3...           Heat
# 127697  App_25_Keywords_Email/MIL_Keywords_Email/Milit...           Heat
# 127702                           App_2_Access_Volume_7day           Heat
# 127703                        App_3_Critical_Egress_Email         Atomic
# 127704  Email_Attachments_To_Competitor_Domain/Thresho...           Heat
# 127708                           App_3_To_Internet_upload         Atomic
# 127709                           App_3_To_Internet_upload         Atomic
#
#           alert_type   grouping indicator_heat_score  alert_id
# 0         Daily_Heat      App_1                  3.0     60095
# 1         Daily_Heat      App_1                  3.0     60164
# 5       Monthly_Heat      App_1                  3.0     60128
# 6       Monthly_Heat  Threshold                  0.0     60114
# 11        Daily_Heat      App_1                  3.0     60141
# 12            Atomic      App_1                  NaN     35163
# 13            Atomic      App_1                  NaN     34985
# 14        Daily_Heat      App_3                 20.0     60108
# 15        Daily_Heat      App_1                  3.0     60109
# 16      Monthly_Heat      App_2                 40.0     60102
# 18        Daily_Heat      App_3                 20.0     60105
# 19            Atomic      App_3                  NaN     34109
# 20            Atomic      App_3                  NaN     34113
# 21            Atomic      App_3                  NaN     34115
# 22            Atomic      App_3                  NaN     34119
# 23       Weekly_Heat  Threshold                  0.0     60110
# 28        Daily_Heat  Threshold                  0.0     60153
# 31      Monthly_Heat      App_2                 40.0     60165
# 37      Monthly_Heat  Threshold                  0.0     60154
# 44        Daily_Heat      App_3                 20.0     60113
# 45        Daily_Heat      App_3                 20.0     60087
# 46        Daily_Heat  Threshold                  0.0     60150
# 49      Monthly_Heat     App_14                  3.0     60178
# 55        Daily_Heat      App_3                 20.0     60103
# 56       Weekly_Heat  Threshold                  0.0     60132
# 61            Atomic      App_3                  NaN     35084
# 62            Atomic      App_3                  NaN     34999
# 63      Monthly_Heat  Threshold                  0.0     60182
# 68       Weekly_Heat      App_2                 40.0     60106
# 75       Weekly_Heat  Threshold                  0.0     60116
# ...              ...        ...                  ...       ...
# 127641  Monthly_Heat     App_25                  0.0     38691
# 127644        Atomic     App_17                  NaN     38683
# 127645        Atomic     App_17                  NaN     38681
# 127646        Atomic     App_17                  NaN     38680
# 127647        Atomic     App_17                  NaN     38682
# 127648        Atomic     App_17                  NaN     38676
# 127649        Atomic     App_17                  NaN     38679
# 127650        Atomic     App_17                  NaN     38686
# 127651        Atomic     App_17                  NaN     38677
# 127652        Atomic     App_17                  NaN     38685
# 127653        Atomic     App_17                  NaN     38678
# 127654        Atomic     App_17                  NaN     38684
# 127655  Monthly_Heat  Threshold                  0.0     38748
# 127658  Monthly_Heat     App_25                 10.0     38702
# 127663        Atomic      App_3                  NaN     38761
# 127664    Daily_Heat  Threshold                  0.0     38763
# 127669        Atomic      App_3                  NaN     38762
# 127670   Weekly_Heat      App_2                 40.0     38765
# 127675    Daily_Heat      App_3                  5.0     38774
# 127678    Daily_Heat      App_2                  3.0     38773
# 127681   Weekly_Heat      Email                  3.0     38776
# 127685  Monthly_Heat      Email                  3.0     38769
# 127688  Monthly_Heat      Email                  3.0     38767
# 127690  Monthly_Heat  Threshold                  0.0     38766
# 127697  Monthly_Heat     App_25                 10.0     38770
# 127702  Monthly_Heat      App_2                 50.0     38764
# 127703        Atomic      App_3                  NaN     38768
# 127704   Weekly_Heat      Email                  3.0     38775
# 127708        Atomic      App_3                  NaN     38772
# 127709        Atomic      App_3                  NaN     38771
#
# [100467 rows x 21 columns]

# %% [markdown]
# ### This is the dataset we are going to use! 100467 observations!  But the dataset seems to have some issues: the same id with different classifications. We keep them for now. You can also use this code below to see them.
#
# code for: see the remaining duplicated alert_id_fk with different classification
#
# df["is_duplicate"]= df.duplicated('alert_id_fk')
#
# df

# %%
df['malicious'].value_counts()
# Out:
# no     59406
# yes    41061
# Name: malicious, dtype: int64

# %%
df['classification'].value_counts()
# Out:
# FP         58166
# TP/DE      38397
# TP/LOW      2977
# TP/HIGH      927
# Name: classification, dtype: int64

# %%
df['owner_name'].value_counts()
# Out:
# Senior_Analyst_1    62848
# Analyst_4           20301
# Analyst_6            7732
# Analyst_1            6449
# Senior_Analyst_2     2820
# Analyst_5             275
# Analyst_3              40
# Analyst_2               2
# Name: owner_name, dtype: int64

# %%
df['alert_type'].value_counts()
# Out:
# Atomic          83555
# Daily_Heat       6350
# Monthly_Heat     5601
# Weekly_Heat      4961
# Name: alert_type, dtype: int64

# %%
df.describe()
# Out:
#         alert_id_fk         score   employee_id   risk_factor      avg_score  \
# count  1.004670e+05  1.004670e+05  1.004670e+05  16913.000000   16913.000000
# mean   1.231696e+09  6.986368e+02  1.269093e+10      9.990245     407.922840
# std    5.922199e+08  8.622630e+03  8.449072e+09     12.473719    1777.541185
# min    1.113526e+06  3.000000e+00  9.063716e+07      1.700483       5.000000
# 25%    7.437939e+08  1.000000e+01  5.160501e+09      2.926829     100.000000
# 50%    1.357951e+09  1.000000e+01  1.438460e+10      7.930000     110.000000
# 75%    1.753090e+09  1.000000e+01  1.870197e+10     11.566667     245.000000
# max    2.189938e+09  1.147968e+06  5.024200e+10    629.645161  113727.000000
#
#        indicator_heat_score       alert_id
# count          64943.000000  100467.000000
# mean               4.185547   50233.000000
# std                6.668003   29002.469085
# min                0.000000       0.000000
# 25%                3.000000   25116.500000
# 50%                3.000000   50233.000000
# 75%                3.000000   75349.500000
# max               50.000000  100466.000000

# %%
# to see the unique value for each columns 
# for each column in my column names:
for c in list(df.columns):
    
    # get a list of unique values
    n = df[c].unique()
    
    # if number of unique values is less than 30, print the values. Otherwise print the number of unique values
    if len(n)<30:
        print(c)
        print(n)
    else:
        print(c + ': ' +str(len(n)) + ' unique values')
# Out:
# type_name
# ['TP' 'FP' 'TP/LOW' 'TP/HIGH']
# alert_escalation_date: 4489 unique values
# alert_id_fk: 99894 unique values
# insert_date: 457 unique values
# score: 4863 unique values
# status
# ['cleared' 'confirmed']
# resolution
# ['closed' 'in_progress']
# owner_name
# ['Senior_Analyst_1' 'Analyst_4' 'Analyst_5' 'Senior_Analyst_2' 'Analyst_1'
#  'Analyst_6' 'Analyst_2' 'Analyst_3']
# malicious
# ['yes' 'no']
# employee_id: 1390 unique values
# risk_factor: 10359 unique values
# avg_score: 1628 unique values
# classification
# ['TP/DE' 'FP' 'TP/LOW' 'TP/HIGH']
# HRU
# ['None' 'HRU11' 'HRU13' 'HRU12' 'HRU19' 'HRU18' 'HRU3' 'HRU2' 'HRU' 'HRU5'
#  'HRU7' 'HRU6']
# indicators: 60 unique values
# indicator_pairs: 634 unique values
# alert_category
# ['Heat' 'Atomic' 'Unknown_Error']
# alert_type
# ['Daily_Heat' 'Monthly_Heat' 'Atomic' 'Weekly_Heat']
# grouping
# ['App_1' 'Threshold' 'App_3' 'App_2' 'App_14' 'App_15' 'App_11' 'Email'
#  'Top_Users' 'App_4' 'Badge' 'App_8' 'Unknown' 'App_18' 'App_13' 'App_21'
#  'App_17' 'App_22' 'App_25' 'Military_Keywords' 'App_5']
# indicator_heat_score
# [ 3.  0. nan 20. 40.  5.  2.  1.  4. 50. 30. 10.]
# alert_id: 100467 unique values

# %%
# load demographics (edited, only current employees) csv into dataframe df2
df2 = pd.read_csv('demographics_edited.csv')
df2.head()
# Out:
#    employee_id Person_Type     GE_Hire_Date           Today  days  work_years  \
# 0   4163677584    Employee  11/19/2018 0:00  4/10/2019 0:00   142        0.39
# 1  17613200261    Employee   11/5/2018 0:00  4/10/2019 0:00   156        0.43
# 2  19409121849    Employee   11/5/2018 0:00  4/10/2019 0:00   156        0.43
# 3   1634096764    Employee  10/22/2018 0:00  4/10/2019 0:00   170        0.47
# 4  19834443347    Employee  10/15/2018 0:00  4/10/2019 0:00   177        0.48
#
#    tenure_level      State_Name   Country_Name COUNTRY_CODE  \
# 0             1        Delaware  United States           US
# 1             1   Massachusetts  United States           US
# 2             1   Massachusetts  United States           US
# 3             1        Delaware  United States           US
# 4             1  North Carolina  United States           US
#
#         Business_Segment                                       Sub_Business  \
# 0  Aviation Supply Chain  AVI SC-EHS & Security & Facilities & Health Se...
# 1   Aviation Engineering    AVI ENG-Military Propulsion & Power Engineering
# 2   Aviation Engineering    AVI ENG-Military Propulsion & Power Engineering
# 3  Aviation Supply Chain                   AVI SC-Ceramic Matrix Composites
# 4  Aviation Supply Chain                                     AVI SC-Quality
#
#                         Function Function_Group  \
# 0  Environmental Health & Safety       Enabling
# 1         Engineering/Technology     Production
# 2         Engineering/Technology     Production
# 3                  Manufacturing     Production
# 4                        Quality       Enabling
#
#                                             Org_Name Career_Band JOB_TITLE  \
# 0  AVI SC-EHS & Security & Facilities & Health Se...          PB   No_Data
# 1    AVI ENG-MP&PE-Lynn TurboFan TurboJet Design Eng          PB   No_Data
# 2              AVI ENG-MP&PE-ITEP Design Engineering          PB   No_Data
# 3                            AVI SC-CMC-CMC SC Staff          PB   No_Data
# 4                             AVI SC-QUAL-Composites         SPB   No_Data
#
#                                           JOB_TYPE
# 0  Specialist 2 Operational EHS - Fixed Facilities
# 1                Engineer 2 - Mechanical Component
# 2                Engineer 2 - Controls Engineering
# 3            Manufacturing Specialist 1 - Training
# 4     Sr Quality Manager 3 - Production Regulation

# %%
df2.groupby('Function_Group').size()
# Out:
# Function_Group
# Commercial     56
# Enabling      129
# Production    815
# dtype: int64

# %%
df2.describe()
# Out:
#         employee_id          days   work_years  tenure_level
# count  1.000000e+03   1000.000000  1000.000000   1000.000000
# mean   1.346606e+10   4266.002000    11.687600      2.561000
# std    6.983593e+09   3405.782831     9.330815      1.608374
# min    9.063716e+07    142.000000     0.390000      1.000000
# 25%    7.279091e+09   1794.000000     4.920000      1.000000
# 50%    1.440092e+10   3145.000000     8.620000      2.000000
# 75%    1.981132e+10   5305.000000    14.532500      3.000000
# max    3.248596e+10  14996.000000    41.080000      7.000000

# %% [markdown]
# # prepare the output label = malicious

# %%
df['OUTPUT_LABEL'] = df.malicious
# Out:
# C:\Users\minyi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df[['OUTPUT_LABEL']].head()
# Out:
#    OUTPUT_LABEL
# 0           yes
# 1           yes
# 5           yes
# 6           yes
# 11          yes

# %%
dfa=df.replace({'OUTPUT_LABEL': {'yes': 1, 'no': 0}})
dfa[['OUTPUT_LABEL']].head()
# Out:
#     OUTPUT_LABEL
# 0              1
# 1              1
# 5              1
# 6              1
# 11             1

# %%
def calc_prevalence(y_actual):
    # this function calculates the prevalence of the positive class (label = 1)
    return (sum(y_actual)/len(y_actual))

# %%
print('prevalence of the positive class: %.3f'%calc_prevalence(dfa['OUTPUT_LABEL'].values))
# Out:
# prevalence of the positive class: 0.409

# %% [markdown]
# # Prepare the input features from dataset df

# %%
cols_input = ['classification','owner_name','alert_type'] + ['score']+['employee_id']
dfb = dfa[cols_input + ['OUTPUT_LABEL']]
dfb
# Out:
#        classification        owner_name    alert_type  score  employee_id  \
# 0               TP/DE  Senior_Analyst_1    Daily_Heat    180   2313834724
# 1               TP/DE  Senior_Analyst_1    Daily_Heat    172  13152813815
# 5               TP/DE  Senior_Analyst_1  Monthly_Heat    873  20533197492
# 6               TP/DE  Senior_Analyst_1  Monthly_Heat    811  20992423005
# 11              TP/DE  Senior_Analyst_1    Daily_Heat    195   2313834724
# 12                 FP  Senior_Analyst_1        Atomic     10  13732187617
# 13                 FP  Senior_Analyst_1        Atomic     10  13732187617
# 14              TP/DE  Senior_Analyst_1    Daily_Heat    200   9476086518
# 15              TP/DE  Senior_Analyst_1    Daily_Heat    174   2313834724
# 16              TP/DE  Senior_Analyst_1  Monthly_Heat   1520   1806090031
# 18              TP/DE  Senior_Analyst_1    Daily_Heat    360  16955391895
# 19                 FP  Senior_Analyst_1        Atomic     10  21238056044
# 20                 FP  Senior_Analyst_1        Atomic     10  21238056044
# 21                 FP  Senior_Analyst_1        Atomic     10  21238056044
# 22                 FP  Senior_Analyst_1        Atomic     10  21238056044
# 23              TP/DE  Senior_Analyst_1   Weekly_Heat   1376  14917297624
# 28              TP/DE  Senior_Analyst_1    Daily_Heat    220  17021981216
# 31              TP/DE  Senior_Analyst_1  Monthly_Heat   1095  12410466738
# 37              TP/DE  Senior_Analyst_1  Monthly_Heat   1053  19331541121
# 44              TP/DE  Senior_Analyst_1    Daily_Heat    200   9476086518
# 45              TP/DE  Senior_Analyst_1    Daily_Heat    360  16955391895
# 46              TP/DE  Senior_Analyst_1    Daily_Heat    220  17021981216
# 49              TP/DE  Senior_Analyst_1  Monthly_Heat   2008  20603367907
# 55              TP/DE  Senior_Analyst_1    Daily_Heat    200   9476086518
# 56              TP/DE  Senior_Analyst_1   Weekly_Heat   1370  14917297624
# 61                 FP  Senior_Analyst_1        Atomic     10   5661237279
# 62                 FP  Senior_Analyst_1        Atomic     10   5661237279
# 63              TP/DE  Senior_Analyst_1  Monthly_Heat    851  20992423005
# 68              TP/DE  Senior_Analyst_1   Weekly_Heat    544  20994653327
# 75              TP/DE  Senior_Analyst_1   Weekly_Heat   1376  14917297624
# ...               ...               ...           ...    ...          ...
# 127641          TP/DE         Analyst_4  Monthly_Heat   1163    447642540
# 127644         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127645         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127646         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127647         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127648         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127649         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127650         TP/LOW         Analyst_4        Atomic     10  20991899571
# 127651         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127652         TP/LOW         Analyst_4        Atomic     10  20991899571
# 127653         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127654         TP/LOW         Analyst_4        Atomic     10   5967617013
# 127655         TP/LOW         Analyst_6  Monthly_Heat    740  46813231276
# 127658          TP/DE         Analyst_4  Monthly_Heat   1114  17112580659
# 127663          TP/DE         Analyst_4        Atomic     10   1895149041
# 127664         TP/LOW         Analyst_6    Daily_Heat    174  11636921589
# 127669          TP/DE         Analyst_6        Atomic     10   6945283463
# 127670          TP/DE         Analyst_1   Weekly_Heat    723  10719547234
# 127675          TP/DE         Analyst_1    Daily_Heat    232  18684782559
# 127678          TP/DE         Analyst_1    Daily_Heat    243  32064643741
# 127681          TP/DE         Analyst_6   Weekly_Heat    516   1543875646
# 127685          TP/DE         Analyst_4  Monthly_Heat  23441  14812664119
# 127688          TP/DE         Analyst_4  Monthly_Heat  11199   2313727843
# 127690          TP/DE         Analyst_1  Monthly_Heat    766  10719547234
# 127697          TP/DE         Analyst_4  Monthly_Heat   1160  17112580659
# 127702          TP/DE         Analyst_4  Monthly_Heat   2000  18282552322
# 127703          TP/DE         Analyst_1        Atomic     10  17666907117
# 127704          TP/DE         Analyst_6   Weekly_Heat    522   1543875646
# 127708          TP/DE         Analyst_1        Atomic     10  17952231743
# 127709          TP/DE         Analyst_1        Atomic     10  17952231743
#
#         OUTPUT_LABEL
# 0                  1
# 1                  1
# 5                  1
# 6                  1
# 11                 1
# 12                 0
# 13                 0
# 14                 1
# 15                 1
# 16                 1
# 18                 1
# 19                 0
# 20                 0
# 21                 0
# 22                 0
# 23                 1
# 28                 1
# 31                 1
# 37                 1
# 44                 1
# 45                 1
# 46                 1
# 49                 1
# 55                 1
# 56                 1
# 61                 0
# 62                 0
# 63                 1
# 68                 1
# 75                 1
# ...              ...
# 127641             1
# 127644             1
# 127645             1
# 127646             1
# 127647             1
# 127648             1
# 127649             1
# 127650             1
# 127651             1
# 127652             1
# 127653             1
# 127654             1
# 127655             1
# 127658             1
# 127663             1
# 127664             0
# 127669             1
# 127670             1
# 127675             1
# 127678             1
# 127681             1
# 127685             1
# 127688             1
# 127690             1
# 127697             1
# 127702             1
# 127703             1
# 127704             1
# 127708             1
# 127709             1
#
# [100467 rows x 6 columns]

# %%
#check missing value
dfb.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# OUTPUT_LABEL      0
# employee_id       0
# score             0
# alert_type        0
# owner_name        0
# classification    0
# dtype: int64

# %% [markdown]
# # Prepare the input features from dataset df2

# %%
cols_input1 = ['tenure_level','Function_Group','employee_id']
df2a = df2[cols_input1]
df2a
# Out:
#      tenure_level Function_Group  employee_id
# 0               1       Enabling   4163677584
# 1               1     Production  17613200261
# 2               1     Production  19409121849
# 3               1     Production   1634096764
# 4               1       Enabling  19834443347
# 5               1       Enabling  19557528011
# 6               1     Production  19103894369
# 7               1       Enabling   4978111160
# 8               1     Production  12835323492
# 9               1     Production  21211119722
# 10              1     Production  12898650340
# 11              1     Production   1281439061
# 12              1       Enabling  14197584051
# 13              1     Production   2798153748
# 14              1     Production  15685475919
# 15              1     Production  18061016726
# 16              1     Production    909862072
# 17              1     Production   9274206483
# 18              1     Production  21188941317
# 19              1       Enabling   5419605220
# 20              1     Production   5416897478
# 21              1       Enabling   1281380049
# 22              1       Enabling   1281380049
# 23              1       Enabling  17271118218
# 24              1       Enabling  15612248707
# 25              1       Enabling   7415969231
# 26              1     Commercial   9273774710
# 27              1     Production   9728905982
# 28              1     Production  11452135638
# 29              1     Commercial   2227194875
# ..            ...            ...          ...
# 970             6     Production   6535633127
# 971             6       Enabling   7020559518
# 972             6     Production   3998757874
# 973             6     Production  18439559493
# 974             6     Production   7020566371
# 975             6     Production  20251335991
# 976             6     Production  17869731621
# 977             6     Production  13666544183
# 978             6     Production  20250390553
# 979             6     Commercial   7895728189
# 980             7     Production  13149720848
# 981             7     Production   2313401859
# 982             7     Production  20842245300
# 983             7     Production  20528309357
# 984             7     Production  13150935719
# 985             7     Production  14397139531
# 986             7     Production  19298729910
# 987             7     Production  20483919942
# 988             7     Production  20306041287
# 989             7     Production   7871345352
# 990             7     Production   7725435612
# 991             7     Production  14264272986
# 992             7       Enabling   3225522111
# 993             7     Production   5568769466
# 994             7     Production  17540620514
# 995             7     Commercial   3930955969
# 996             7     Production   3318674302
# 997             7     Commercial   6619074875
# 998             7     Production  14164700621
# 999             7     Production  16455521187
#
# [1000 rows x 3 columns]

# %%
#check missing value
df2a.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# employee_id       0
# Function_Group    0
# tenure_level      0
# dtype: int64

# %% [markdown]
# # merge two prepared datasets

# %%
df3=pd.merge(dfb, df2a, on='employee_id')
df3
# Out:
#       classification        owner_name    alert_type  score  employee_id  \
# 0              TP/DE  Senior_Analyst_1    Daily_Heat    172  13152813815
# 1              TP/DE  Senior_Analyst_1    Daily_Heat    256  13152813815
# 2              TP/DE  Senior_Analyst_1    Daily_Heat    277  13152813815
# 3              TP/DE  Senior_Analyst_1    Daily_Heat    274  13152813815
# 4              TP/DE  Senior_Analyst_1    Daily_Heat    289  13152813815
# 5              TP/DE  Senior_Analyst_1    Daily_Heat    289  13152813815
# 6              TP/DE  Senior_Analyst_1    Daily_Heat    286  13152813815
# 7              TP/DE  Senior_Analyst_1    Daily_Heat    274  13152813815
# 8              TP/DE  Senior_Analyst_1    Daily_Heat    253  13152813815
# 9              TP/DE  Senior_Analyst_1    Daily_Heat    223  13152813815
# 10             TP/DE  Senior_Analyst_1    Daily_Heat    189  13152813815
# 11             TP/DE  Senior_Analyst_1    Daily_Heat    177  13152813815
# 12             TP/DE  Senior_Analyst_1    Daily_Heat    177  13152813815
# 13             TP/DE  Senior_Analyst_1    Daily_Heat    171  13152813815
# 14             TP/DE  Senior_Analyst_1    Daily_Heat    180  13152813815
# 15             TP/DE  Senior_Analyst_1    Daily_Heat    186  13152813815
# 16             TP/DE  Senior_Analyst_1    Daily_Heat    189  13152813815
# 17             TP/DE  Senior_Analyst_1    Daily_Heat    174  13152813815
# 18             TP/DE  Senior_Analyst_1    Daily_Heat    198  13152813815
# 19             TP/DE  Senior_Analyst_1    Daily_Heat    240  13152813815
# 20             TP/DE  Senior_Analyst_1    Daily_Heat    282  13152813815
# 21             TP/DE  Senior_Analyst_1    Daily_Heat    282  13152813815
# 22             TP/DE  Senior_Analyst_1    Daily_Heat    276  13152813815
# 23             TP/DE  Senior_Analyst_1    Daily_Heat    279  13152813815
# 24             TP/DE  Senior_Analyst_1    Daily_Heat    273  13152813815
# 25             TP/DE  Senior_Analyst_1    Daily_Heat    288  13152813815
# 26             TP/DE  Senior_Analyst_1    Daily_Heat    285  13152813815
# 27             TP/DE  Senior_Analyst_1    Daily_Heat    282  13152813815
# 28             TP/DE  Senior_Analyst_1    Daily_Heat    252  13152813815
# 29             TP/DE  Senior_Analyst_1    Daily_Heat    231  13152813815
# ...              ...               ...           ...    ...          ...
# 92489          TP/DE         Analyst_6   Weekly_Heat    516   1543875646
# 92490          TP/DE         Analyst_6   Weekly_Heat    522   1543875646
# 92491          TP/DE         Analyst_4   Weekly_Heat    458   1895420670
# 92492          TP/DE         Analyst_4   Weekly_Heat    510   1895420670
# 92493          TP/DE         Analyst_4   Weekly_Heat    560   1895420670
# 92494          TP/DE         Analyst_4   Weekly_Heat    612   1895420670
# 92495          TP/DE         Analyst_4    Daily_Heat    204   7020552900
# 92496          TP/DE         Analyst_4    Daily_Heat    204   7020552900
# 92497          TP/DE         Analyst_4    Daily_Heat    204   7020552900
# 92498          TP/DE         Analyst_4  Monthly_Heat   1017  12407018415
# 92499          TP/DE         Analyst_4  Monthly_Heat   1044  12407018415
# 92500         TP/LOW         Analyst_4        Atomic     10  20991899571
# 92501         TP/LOW         Analyst_4        Atomic     10  20991899571
# 92502         TP/LOW         Analyst_4        Atomic     10  20991899571
# 92503          TP/DE         Analyst_6        Atomic     10   3318514707
# 92504          TP/DE         Analyst_6        Atomic     10   3318514707
# 92505          TP/DE         Analyst_6        Atomic     10   3318514707
# 92506          TP/DE         Analyst_6        Atomic     10  17952231743
# 92507          TP/DE         Analyst_1        Atomic     10  17952231743
# 92508          TP/DE         Analyst_1        Atomic     10  17952231743
# 92509          TP/DE         Analyst_6        Atomic     10  20250390746
# 92510          TP/DE         Analyst_6        Atomic     10  20250390746
# 92511          TP/DE         Analyst_6        Atomic     10  20250390746
# 92512          TP/DE         Analyst_6        Atomic     10  20250390746
# 92513          TP/DE         Analyst_6        Atomic     10   3389273306
# 92514          TP/DE         Analyst_4  Monthly_Heat    970  14197584051
# 92515          TP/DE         Analyst_4   Weekly_Heat    476  18684782559
# 92516          TP/DE         Analyst_4    Daily_Heat    232  18684782559
# 92517          TP/DE         Analyst_4    Daily_Heat    232  18684782559
# 92518          TP/DE         Analyst_1    Daily_Heat    232  18684782559
#
#        OUTPUT_LABEL  tenure_level Function_Group
# 0                 1             3     Production
# 1                 1             3     Production
# 2                 1             3     Production
# 3                 1             3     Production
# 4                 1             3     Production
# 5                 1             3     Production
# 6                 1             3     Production
# 7                 1             3     Production
# 8                 1             3     Production
# 9                 1             3     Production
# 10                1             3     Production
# 11                1             3     Production
# 12                1             3     Production
# 13                1             3     Production
# 14                1             3     Production
# 15                1             3     Production
# 16                1             3     Production
# 17                1             3     Production
# 18                1             3     Production
# 19                1             3     Production
# 20                1             3     Production
# 21                1             3     Production
# 22                1             3     Production
# 23                1             3     Production
# 24                1             3     Production
# 25                1             3     Production
# 26                1             3     Production
# 27                1             3     Production
# 28                1             3     Production
# 29                1             3     Production
# ...             ...           ...            ...
# 92489             1             1     Production
# 92490             1             1     Production
# 92491             1             2     Production
# 92492             1             2     Production
# 92493             1             2     Production
# 92494             1             2     Production
# 92495             1             6     Production
# 92496             1             6     Production
# 92497             1             6     Production
# 92498             1             6     Production
# 92499             1             6     Production
# 92500             1             2     Production
# 92501             1             2     Production
# 92502             1             2     Production
# 92503             1             4     Commercial
# 92504             1             4     Commercial
# 92505             1             4     Commercial
# 92506             1             2       Enabling
# 92507             1             2       Enabling
# 92508             1             2       Enabling
# 92509             1             4     Production
# 92510             1             4     Production
# 92511             1             4     Production
# 92512             1             4     Production
# 92513             1             1     Production
# 92514             1             1       Enabling
# 92515             1             3     Production
# 92516             1             3     Production
# 92517             1             3     Production
# 92518             1             3     Production
#
# [92519 rows x 8 columns]

# %%
# now we use df3
print('prevalence of the positive class: %.3f'%calc_prevalence(df3['OUTPUT_LABEL'].values))
# Out:
# prevalence of the positive class: 0.388

# %%
df3.groupby('OUTPUT_LABEL').size()
# Out:
# OUTPUT_LABEL
# 0    56630
# 1    35889
# dtype: int64

# %% [markdown]
# # The dataset we are going to use df3:
# # Output label: malicious = OUTPUT LABEL (38.8% are malicious)
# # Numerical feature: score, work_years
# # Nominal Categorical features: owner_name, alert_type, Function_Group
# # Ordinal Categorical features: classification

# %% [markdown]
# ### Nominal categorical features
#
# One-hot encoding
#
# One-hot encoding means we will creat a new column for each unique value in that column. Normally, we will do this for our categorical features. For example, gender column has female and male. We will create two new columns, one is for female, and another one is for male. If the invidual is female, it will be 1. If not, it will be 0. To create these one-hot encoding columns, we use the get_dummies function. We will use the prefix option, so that we know where the new columns come from.
#
# In order to reduce the correlated columns, we would need to drop the first categorical value. This can be done by the drop_first option. Correlated columns problem means that we don't need all columns because we can figure out the last columns by looking at other columns. For example, we don't need both female and male columns. We can just keep one. If the individual is 0 then we know he is male.

# %%
cols_cat = ['owner_name', 'alert_type', 'Function_Group']

# %%
# The get_dummies function does not work on numerical data. 
# To trick get_dummies, we can convert the numerical data into strings and then it will work properly.
#convert the numerical data into strings 
df3[cols_cat] = df3[cols_cat].astype('str')

# %%
# Use one-hot encoding technique, that is to use get_dummies function in python
# drop the first column to reduce the correlated columns
# We can do this at once for all three categorical features
df_cat = pd.get_dummies(df3[cols_cat],drop_first = True)

# %%
# show first 5 rows
df_cat.head()
# Out:
#    owner_name_Analyst_3  owner_name_Analyst_4  owner_name_Analyst_5  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    owner_name_Analyst_6  owner_name_Senior_Analyst_1  \
# 0                     0                            1
# 1                     0                            1
# 2                     0                            1
# 3                     0                            1
# 4                     0                            1
#
#    owner_name_Senior_Analyst_2  alert_type_Daily_Heat  \
# 0                            0                      1
# 1                            0                      1
# 2                            0                      1
# 3                            0                      1
# 4                            0                      1
#
#    alert_type_Monthly_Heat  alert_type_Weekly_Heat  Function_Group_Enabling  \
# 0                        0                       0                        0
# 1                        0                       0                        0
# 2                        0                       0                        0
# 3                        0                       0                        0
# 4                        0                       0                        0
#
#    Function_Group_Production
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1

# %%
df3.groupby('owner_name').size()
# Out:
# owner_name
# Analyst_1            5393
# Analyst_3              40
# Analyst_4           16758
# Analyst_5             275
# Analyst_6            7380
# Senior_Analyst_1    61467
# Senior_Analyst_2     1206
# dtype: int64

# %%
df3.groupby('alert_type').size()
# Out:
# alert_type
# Atomic          81314
# Daily_Heat       4084
# Monthly_Heat     4035
# Weekly_Heat      3086
# dtype: int64

# %%
df3.groupby('Function_Group').size()
# Out:
# Function_Group
# Commercial      856
# Enabling       1751
# Production    89912
# dtype: int64

# %%
# To add the one-hot encoding columns to the dataframe we can use concat function. 
# Make sure to use axis = 1 to indicate add the columns.
df3 = pd.concat([df3,df_cat], axis = 1)

# %%
# Save the column names of the categorical data.
cols_all_cat = list(df_cat.columns)

# %% [markdown]
# ### Ordinal Categorical feature

# %%
df3.groupby('classification').size()
# Out:
# classification
# FP         55461
# TP/DE      34269
# TP/HIGH      888
# TP/LOW      1901
# dtype: int64

# %%
# Let's map the value into numbers
cl_id = {'FP':0, 
         'TP/DE':1, 
         'TP/LOW':2,
         'TP/HIGH':3,}
df3['classification'] = df3.classification.replace(cl_id)

# %%
df3['classification'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: classification, dtype: int64

# %%
df3.head()
# Out:
#    classification        owner_name  alert_type  score  employee_id  \
# 0               1  Senior_Analyst_1  Daily_Heat    172  13152813815
# 1               1  Senior_Analyst_1  Daily_Heat    256  13152813815
# 2               1  Senior_Analyst_1  Daily_Heat    277  13152813815
# 3               1  Senior_Analyst_1  Daily_Heat    274  13152813815
# 4               1  Senior_Analyst_1  Daily_Heat    289  13152813815
#
#    OUTPUT_LABEL  tenure_level Function_Group  owner_name_Analyst_3  \
# 0             1             3     Production                     0
# 1             1             3     Production                     0
# 2             1             3     Production                     0
# 3             1             3     Production                     0
# 4             1             3     Production                     0
#
#    owner_name_Analyst_4  owner_name_Analyst_5  owner_name_Analyst_6  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    owner_name_Senior_Analyst_1  owner_name_Senior_Analyst_2  \
# 0                            1                            0
# 1                            1                            0
# 2                            1                            0
# 3                            1                            0
# 4                            1                            0
#
#    alert_type_Daily_Heat  alert_type_Monthly_Heat  alert_type_Weekly_Heat  \
# 0                      1                        0                       0
# 1                      1                        0                       0
# 2                      1                        0                       0
# 3                      1                        0                       0
# 4                      1                        0                       0
#
#    Function_Group_Enabling  Function_Group_Production
# 0                        0                          1
# 1                        0                          1
# 2                        0                          1
# 3                        0                          1
# 4                        0                          1

# %%
# only keep the columns we want
cols_input = ['score','tenure_level'] + ['classification'] + cols_all_cat
df_data = df3[cols_input + ['OUTPUT_LABEL']]

# %%
df_data
# Out:
#        score  tenure_level  classification  owner_name_Analyst_3  \
# 0        172             3               1                     0
# 1        256             3               1                     0
# 2        277             3               1                     0
# 3        274             3               1                     0
# 4        289             3               1                     0
# 5        289             3               1                     0
# 6        286             3               1                     0
# 7        274             3               1                     0
# 8        253             3               1                     0
# 9        223             3               1                     0
# 10       189             3               1                     0
# 11       177             3               1                     0
# 12       177             3               1                     0
# 13       171             3               1                     0
# 14       180             3               1                     0
# 15       186             3               1                     0
# 16       189             3               1                     0
# 17       174             3               1                     0
# 18       198             3               1                     0
# 19       240             3               1                     0
# 20       282             3               1                     0
# 21       282             3               1                     0
# 22       276             3               1                     0
# 23       279             3               1                     0
# 24       273             3               1                     0
# 25       288             3               1                     0
# 26       285             3               1                     0
# 27       282             3               1                     0
# 28       252             3               1                     0
# 29       231             3               1                     0
# ...      ...           ...             ...                   ...
# 92489    516             1               1                     0
# 92490    522             1               1                     0
# 92491    458             2               1                     0
# 92492    510             2               1                     0
# 92493    560             2               1                     0
# 92494    612             2               1                     0
# 92495    204             6               1                     0
# 92496    204             6               1                     0
# 92497    204             6               1                     0
# 92498   1017             6               1                     0
# 92499   1044             6               1                     0
# 92500     10             2               2                     0
# 92501     10             2               2                     0
# 92502     10             2               2                     0
# 92503     10             4               1                     0
# 92504     10             4               1                     0
# 92505     10             4               1                     0
# 92506     10             2               1                     0
# 92507     10             2               1                     0
# 92508     10             2               1                     0
# 92509     10             4               1                     0
# 92510     10             4               1                     0
# 92511     10             4               1                     0
# 92512     10             4               1                     0
# 92513     10             1               1                     0
# 92514    970             1               1                     0
# 92515    476             3               1                     0
# 92516    232             3               1                     0
# 92517    232             3               1                     0
# 92518    232             3               1                     0
#
#        owner_name_Analyst_4  owner_name_Analyst_5  owner_name_Analyst_6  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# 5                         0                     0                     0
# 6                         0                     0                     0
# 7                         0                     0                     0
# 8                         0                     0                     0
# 9                         0                     0                     0
# 10                        0                     0                     0
# 11                        0                     0                     0
# 12                        0                     0                     0
# 13                        0                     0                     0
# 14                        0                     0                     0
# 15                        0                     0                     0
# 16                        0                     0                     0
# 17                        0                     0                     0
# 18                        0                     0                     0
# 19                        0                     0                     0
# 20                        0                     0                     0
# 21                        0                     0                     0
# 22                        0                     0                     0
# 23                        0                     0                     0
# 24                        0                     0                     0
# 25                        0                     0                     0
# 26                        0                     0                     0
# 27                        0                     0                     0
# 28                        0                     0                     0
# 29                        0                     0                     0
# ...                     ...                   ...                   ...
# 92489                     0                     0                     1
# 92490                     0                     0                     1
# 92491                     1                     0                     0
# 92492                     1                     0                     0
# 92493                     1                     0                     0
# 92494                     1                     0                     0
# 92495                     1                     0                     0
# 92496                     1                     0                     0
# 92497                     1                     0                     0
# 92498                     1                     0                     0
# 92499                     1                     0                     0
# 92500                     1                     0                     0
# 92501                     1                     0                     0
# 92502                     1                     0                     0
# 92503                     0                     0                     1
# 92504                     0                     0                     1
# 92505                     0                     0                     1
# 92506                     0                     0                     1
# 92507                     0                     0                     0
# 92508                     0                     0                     0
# 92509                     0                     0                     1
# 92510                     0                     0                     1
# 92511                     0                     0                     1
# 92512                     0                     0                     1
# 92513                     0                     0                     1
# 92514                     1                     0                     0
# 92515                     1                     0                     0
# 92516                     1                     0                     0
# 92517                     1                     0                     0
# 92518                     0                     0                     0
#
#        owner_name_Senior_Analyst_1  owner_name_Senior_Analyst_2  \
# 0                                1                            0
# 1                                1                            0
# 2                                1                            0
# 3                                1                            0
# 4                                1                            0
# 5                                1                            0
# 6                                1                            0
# 7                                1                            0
# 8                                1                            0
# 9                                1                            0
# 10                               1                            0
# 11                               1                            0
# 12                               1                            0
# 13                               1                            0
# 14                               1                            0
# 15                               1                            0
# 16                               1                            0
# 17                               1                            0
# 18                               1                            0
# 19                               1                            0
# 20                               1                            0
# 21                               1                            0
# 22                               1                            0
# 23                               1                            0
# 24                               1                            0
# 25                               1                            0
# 26                               1                            0
# 27                               1                            0
# 28                               1                            0
# 29                               1                            0
# ...                            ...                          ...
# 92489                            0                            0
# 92490                            0                            0
# 92491                            0                            0
# 92492                            0                            0
# 92493                            0                            0
# 92494                            0                            0
# 92495                            0                            0
# 92496                            0                            0
# 92497                            0                            0
# 92498                            0                            0
# 92499                            0                            0
# 92500                            0                            0
# 92501                            0                            0
# 92502                            0                            0
# 92503                            0                            0
# 92504                            0                            0
# 92505                            0                            0
# 92506                            0                            0
# 92507                            0                            0
# 92508                            0                            0
# 92509                            0                            0
# 92510                            0                            0
# 92511                            0                            0
# 92512                            0                            0
# 92513                            0                            0
# 92514                            0                            0
# 92515                            0                            0
# 92516                            0                            0
# 92517                            0                            0
# 92518                            0                            0
#
#        alert_type_Daily_Heat  alert_type_Monthly_Heat  alert_type_Weekly_Heat  \
# 0                          1                        0                       0
# 1                          1                        0                       0
# 2                          1                        0                       0
# 3                          1                        0                       0
# 4                          1                        0                       0
# 5                          1                        0                       0
# 6                          1                        0                       0
# 7                          1                        0                       0
# 8                          1                        0                       0
# 9                          1                        0                       0
# 10                         1                        0                       0
# 11                         1                        0                       0
# 12                         1                        0                       0
# 13                         1                        0                       0
# 14                         1                        0                       0
# 15                         1                        0                       0
# 16                         1                        0                       0
# 17                         1                        0                       0
# 18                         1                        0                       0
# 19                         1                        0                       0
# 20                         1                        0                       0
# 21                         1                        0                       0
# 22                         1                        0                       0
# 23                         1                        0                       0
# 24                         1                        0                       0
# 25                         1                        0                       0
# 26                         1                        0                       0
# 27                         1                        0                       0
# 28                         1                        0                       0
# 29                         1                        0                       0
# ...                      ...                      ...                     ...
# 92489                      0                        0                       1
# 92490                      0                        0                       1
# 92491                      0                        0                       1
# 92492                      0                        0                       1
# 92493                      0                        0                       1
# 92494                      0                        0                       1
# 92495                      1                        0                       0
# 92496                      1                        0                       0
# 92497                      1                        0                       0
# 92498                      0                        1                       0
# 92499                      0                        1                       0
# 92500                      0                        0                       0
# 92501                      0                        0                       0
# 92502                      0                        0                       0
# 92503                      0                        0                       0
# 92504                      0                        0                       0
# 92505                      0                        0                       0
# 92506                      0                        0                       0
# 92507                      0                        0                       0
# 92508                      0                        0                       0
# 92509                      0                        0                       0
# 92510                      0                        0                       0
# 92511                      0                        0                       0
# 92512                      0                        0                       0
# 92513                      0                        0                       0
# 92514                      0                        1                       0
# 92515                      0                        0                       1
# 92516                      1                        0                       0
# 92517                      1                        0                       0
# 92518                      1                        0                       0
#
#        Function_Group_Enabling  Function_Group_Production  OUTPUT_LABEL
# 0                            0                          1             1
# 1                            0                          1             1
# 2                            0                          1             1
# 3                            0                          1             1
# 4                            0                          1             1
# 5                            0                          1             1
# 6                            0                          1             1
# 7                            0                          1             1
# 8                            0                          1             1
# 9                            0                          1             1
# 10                           0                          1             1
# 11                           0                          1             1
# 12                           0                          1             1
# 13                           0                          1             1
# 14                           0                          1             1
# 15                           0                          1             1
# 16                           0                          1             1
# 17                           0                          1             1
# 18                           0                          1             1
# 19                           0                          1             1
# 20                           0                          1             1
# 21                           0                          1             1
# 22                           0                          1             1
# 23                           0                          1             1
# 24                           0                          1             1
# 25                           0                          1             1
# 26                           0                          1             1
# 27                           0                          1             1
# 28                           0                          1             1
# 29                           0                          1             1
# ...                        ...                        ...           ...
# 92489                        0                          1             1
# 92490                        0                          1             1
# 92491                        0                          1             1
# 92492                        0                          1             1
# 92493                        0                          1             1
# 92494                        0                          1             1
# 92495                        0                          1             1
# 92496                        0                          1             1
# 92497                        0                          1             1
# 92498                        0                          1             1
# 92499                        0                          1             1
# 92500                        0                          1             1
# 92501                        0                          1             1
# 92502                        0                          1             1
# 92503                        0                          0             1
# 92504                        0                          0             1
# 92505                        0                          0             1
# 92506                        1                          0             1
# 92507                        1                          0             1
# 92508                        1                          0             1
# 92509                        0                          1             1
# 92510                        0                          1             1
# 92511                        0                          1             1
# 92512                        0                          1             1
# 92513                        0                          1             1
# 92514                        1                          0             1
# 92515                        0                          1             1
# 92516                        0                          1             1
# 92517                        0                          1             1
# 92518                        0                          1             1
#
# [92519 rows x 15 columns]

# %%
print('prevalence of the positive class: %.3f'%calc_prevalence(df_data['OUTPUT_LABEL'].values))
# Out:
# prevalence of the positive class: 0.388

# %% [markdown]
# # Building Training/Validation/Test Samples

# %%
# shuffle the samples first in case there was some order (e.g. all positive samples on top)
df_data = df_data.sample(n = len(df_data), random_state = 42)
df_data = df_data.reset_index(drop = True)

# %%
# Save 30% of the data as validation and test data 
df_valid_test=df_data.sample(frac=0.30,random_state=42)
print('Split size: %.3f'%(len(df_valid_test)/len(df_data)))
# Out:
# Split size: 0.300

# %%
# now split into test and validation using 50% fraction.
# .drop just drops the rows from df_test to get the rows that were not part of the sample.
df_test = df_valid_test.sample(frac = 0.5, random_state = 42)
df_valid = df_valid_test.drop(df_test.index)

# %%
# use the rest of the data as training data
# use .drop to get the data
df_train_all=df_data.drop(df_valid_test.index)

# %%
# check the prevalence of positive value in all three data set
print('Test prevalence(n = %d):%.3f'%(len(df_test),calc_prevalence(df_test.OUTPUT_LABEL.values)))
print('Valid prevalence(n = %d):%.3f'%(len(df_valid),calc_prevalence(df_valid.OUTPUT_LABEL.values)))
print('Train all prevalence(n = %d):%.3f'%(len(df_train_all), calc_prevalence(df_train_all.OUTPUT_LABEL.values)))
# Out:
# Test prevalence(n = 13878):0.389
# Valid prevalence(n = 13878):0.387
# Train all prevalence(n = 64763):0.388

# %%
# Verify that we use all the data
print('all samples (n = %d)'%len(df_data))
assert len(df_data) == (len(df_test)+len(df_valid)+len(df_train_all)),'math didnt work'
# Out:
# all samples (n = 92519)

# %%
# save datasets, index = False just drops the index from the csv.
df_train_all.to_csv('df_train_all.csv',index=False)
df_valid.to_csv('df_valid.csv',index=False)
df_test.to_csv('df_test.csv',index=False)

# %%
# Let's save the cols_input too with a package called pickle.
import pickle
pickle.dump(cols_input, open('cols_input.sav', 'wb'))

# %%
# filling missing value with mean value
def fill_my_missing(df, df_mean, col2use):
    # This function fills the missing values

    # check the columns are present
    for c in col2use:
        assert c in df.columns, c + ' not in df'
        assert c in df_mean.col.values, c+ 'not in df_mean'
    
    # replace the mean 
    for c in col2use:
        mean_value = df_mean.loc[df_mean.col == c,'mean_val'].values[0]
        df[c] = df[c].fillna(mean_value)
    return df

# %%
# axis=0 means go down the column to make the new ones?
df_mean = df_train_all[cols_input].mean(axis = 0)
# save the means
df_mean.to_csv('df_mean.csv',index=True)

# %%
# load the means so we know how to do it for the test data
df_mean_in = pd.read_csv('df_mean.csv', names =['col','mean_val'])
df_mean_in.head()
# Out:
#                     col    mean_val
# 0                 score  380.319642
# 1          tenure_level    2.087056
# 2        classification    0.440035
# 3  owner_name_Analyst_3    0.000417
# 4  owner_name_Analyst_4    0.180026

# %%
df_train_all = fill_my_missing(df_train_all, df_mean_in, cols_input)
df_valid = fill_my_missing(df_valid, df_mean_in, cols_input)

# %%
# Most machine learning packages like to use an input matrix X and output vector y, so let's create those:
X_train_all = df_train_all[cols_input].values
X_valid = df_valid[cols_input].values

y_train = df_train_all['OUTPUT_LABEL'].values
y_valid = df_valid['OUTPUT_LABEL'].values

print('Training All shapes:',X_train_all.shape, y_train.shape)
print('Validation shapes:',X_valid.shape, y_valid.shape)
# Out:
# Training All shapes: (64763, 14) (64763,)
# Validation shapes: (13878, 14) (13878,)

# %% [markdown]
# Some machine learning models have trouble when the variables are of different size (0-100, vs 0-1000000). To deal with that we can scale the data. Here we will use scikit learn's Standard Scaler which removes the mean and scales to unit variance. Here I will create a scaler using all the training data, but you could use the balanced one if you wanted.
# from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()
scaler.fit(X_train_all)
# Out:
# C:\Users\minyi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# We will need this scaler for the test data, so let's save it using a package called pickle. 
import pickle
scalerfile = 'scaler.sav'
pickle.dump(scaler, open(scalerfile, 'wb'))

# %%
# load it back
scaler = pickle.load(open(scalerfile, 'rb'))

# %%
# transform our data matrices
X_train_tf = scaler.transform(X_train_all)
X_valid_tf = scaler.transform(X_valid)
# Out:
# C:\Users\minyi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# # Modeling

# %%
# show the performance scores
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score
def calc_specificity(y_actual, y_pred, thresh):
    # calculates specificity
    return sum((y_pred < thresh) & (y_actual == 0)) /sum(y_actual ==0)

def print_report(y_actual, y_pred, thresh):
    
    auc = roc_auc_score(y_actual, y_pred)
    accuracy = accuracy_score(y_actual, (y_pred > thresh))
    recall = recall_score(y_actual, (y_pred > thresh))
    precision = precision_score(y_actual, (y_pred > thresh))
    specificity = calc_specificity(y_actual, y_pred, thresh)
    print('AUC:%.3f'%auc)
    print('accuracy:%.3f'%accuracy)
    print('recall:%.3f'%recall)
    print('precision:%.3f'%precision)
    print('specificity:%.3f'%specificity)
    print('prevalence:%.3f'%calc_prevalence(y_actual))
    print(' ')
    return auc, accuracy, recall, precision, specificity

# %%
#Since positive is about 0.38 in the training dataset, let's set our threshold at 0.38 to label a predicted sample as positive.
thresh = 0.38

# %%
# k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors = 100)
knn.fit(X_train_tf, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=100, p=2,
#            weights='uniform')

# %%
y_train_preds = knn.predict_proba(X_train_tf)[:,1]
y_valid_preds = knn.predict_proba(X_valid_tf)[:,1]

print('KNN')
print('Training:')
knn_train_auc, knn_train_accuracy, knn_train_recall, \
    knn_train_precision, knn_train_specificity = print_report(y_train,y_train_preds, thresh)
print('Validation:')
knn_valid_auc, knn_valid_accuracy, knn_valid_recall, \
    knn_valid_precision, knn_valid_specificity = print_report(y_valid,y_valid_preds, thresh)
# Out:
# KNN
# Training:
# AUC:1.000
# accuracy:0.987
# recall:0.997
# precision:0.969
# specificity:0.980
# prevalence:0.388
#
# Validation:
# AUC:1.000
# accuracy:0.986
# recall:0.997
# precision:0.969
# specificity:0.980
# prevalence:0.387

# %% [markdown]
# We have an AUC of 1 that catches 99.7% of the malicious intent when we use a threshold of 0.38.

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state = 42)
lr.fit(X_train_tf, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_train_preds = lr.predict_proba(X_train_tf)[:,1]
y_valid_preds = lr.predict_proba(X_valid_tf)[:,1]

print('Logistic Regression')
print('Training:')
lr_train_auc, lr_train_accuracy, lr_train_recall, \
    lr_train_precision, lr_train_specificity = print_report(y_train,y_train_preds, thresh)
print('Validation:')
lr_valid_auc, lr_valid_accuracy, lr_valid_recall, \
    lr_valid_precision, lr_valid_specificity = print_report(y_valid,y_valid_preds, thresh)
# Out:
# Logistic Regression
# Training:
# AUC:0.980
# accuracy:0.987
# recall:1.000
# precision:0.969
# specificity:0.980
# prevalence:0.388
#
# Validation:
# AUC:0.979
# accuracy:0.987
# recall:1.000
# precision:0.968
# specificity:0.979
# prevalence:0.387

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth = 10, random_state = 42)
tree.fit(X_train_tf, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
y_train_preds = tree.predict_proba(X_train_tf)[:,1]
y_valid_preds = tree.predict_proba(X_valid_tf)[:,1]

print('Decision Tree')
print('Training:')
tree_train_auc, tree_train_accuracy, tree_train_recall, tree_train_precision, tree_train_specificity =print_report(y_train,y_train_preds, thresh)
print('Validation:')
tree_valid_auc, tree_valid_accuracy, tree_valid_recall, tree_valid_precision, tree_valid_specificity = print_report(y_valid,y_valid_preds, thresh)
# Out:
# Decision Tree
# Training:
# AUC:1.000
# accuracy:0.997
# recall:1.000
# precision:0.994
# specificity:0.996
# prevalence:0.388
#
# Validation:
# AUC:1.000
# accuracy:0.997
# recall:1.000
# precision:0.993
# specificity:0.996
# prevalence:0.387

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(max_depth = 6, random_state = 42)
rf.fit(X_train_tf, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_train_preds = rf.predict_proba(X_train_tf)[:,1]
y_valid_preds = rf.predict_proba(X_valid_tf)[:,1]

print('Random Forest')
print('Training:')
rf_train_auc, rf_train_accuracy, rf_train_recall, rf_train_precision, rf_train_specificity =print_report(y_train,y_train_preds, thresh)
print('Validation:')
rf_valid_auc, rf_valid_accuracy, rf_valid_recall, rf_valid_precision, rf_valid_specificity = print_report(y_valid,y_valid_preds, thresh)
# Out:
# Random Forest
# Training:
# AUC:1.000
# accuracy:0.993
# recall:1.000
# precision:0.984
# specificity:0.989
# prevalence:0.388
#
# Validation:
# AUC:1.000
# accuracy:0.994
# recall:1.000
# precision:0.984
# specificity:0.989
# prevalence:0.387

# %%
# Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gbc =GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
     max_depth=3, random_state=42)
gbc.fit(X_train_tf, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=1.0, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=42, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
y_train_preds = gbc.predict_proba(X_train_tf)[:,1]
y_valid_preds = gbc.predict_proba(X_valid_tf)[:,1]

print('Gradient Boosting Classifier')
print('Training:')
gbc_train_auc, gbc_train_accuracy, gbc_train_recall, gbc_train_precision, gbc_train_specificity = print_report(y_train,y_train_preds, thresh)
print('Validation:')
gbc_valid_auc, gbc_valid_accuracy, gbc_valid_recall, gbc_valid_precision, gbc_valid_specificity = print_report(y_valid,y_valid_preds, thresh)
# Out:
# Gradient Boosting Classifier
# Training:
# AUC:0.999
# accuracy:0.998
# recall:0.999
# precision:0.996
# specificity:0.997
# prevalence:0.388
#
# Validation:
# AUC:0.999
# accuracy:0.997
# recall:0.999
# precision:0.995
# specificity:0.997
# prevalence:0.387

# %%
df_results1 = pd.DataFrame({'classifier':['K-nearest neighbors','Logistic Regression','Decision Tree','Random Forest','Gradient Boosting'],
                           'data_set':['valid']*5,
                          'auc':[knn_valid_auc,lr_valid_auc,tree_valid_auc,rf_valid_auc,gbc_valid_auc,]})

# %%
sns.set(style="darkgrid")

# %%
ax = sns.barplot(x="auc", y="classifier", data=df_results1)
ax.set_xlabel('AUC',fontsize = 15)
ax.set_ylabel('Classifier', fontsize = 15)
ax.tick_params(labelsize=15)

# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize = 15)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # feature importance

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state = 42)
lr.fit(X_train_tf, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
feature_importances = pd.DataFrame(lr.coef_[0],
                                   index = cols_input,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)

# %%
feature_importances
# Out:
#                              importance
# classification                 2.721243
# owner_name_Analyst_6           0.212195
# tenure_level                   0.068848
# alert_type_Daily_Heat          0.031428
# alert_type_Weekly_Heat        -0.064043
# owner_name_Analyst_4          -0.084012
# alert_type_Monthly_Heat       -0.085534
# Function_Group_Enabling       -0.129636
# score                         -0.158840
# Function_Group_Production     -0.176493
# owner_name_Senior_Analyst_2   -0.189440
# owner_name_Analyst_5          -0.363172
# owner_name_Analyst_3          -0.395269
# owner_name_Senior_Analyst_1   -0.996643

# %%
num = np.min([50, len(cols_input)])
ylocs = np.arange(num)
# get the feature importance for top num and sort in reverse order
values_to_plot = feature_importances.iloc[:num].values.ravel()[::-1]
feature_labels = list(feature_importances.iloc[:num].index)[::-1]

plt.figure(num=None, figsize=(8, 15), dpi=80, facecolor='w', edgecolor='k');
plt.barh(ylocs, values_to_plot, align = 'center')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.title('Feature Importance Score - Logistic Regression')
plt.yticks(ylocs, feature_labels)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(max_depth = 6, random_state = 42)
rf.fit(X_train_tf, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
feature_importances1 = pd.DataFrame(rf.feature_importances_,
                                   index = cols_input,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importances1.head()
# Out:
#                              importance
# classification                 0.679890
# owner_name_Analyst_4           0.132995
# owner_name_Senior_Analyst_1    0.109629
# owner_name_Analyst_6           0.027400
# tenure_level                   0.016681

# %%
num = np.min([50, len(cols_input)])
ylocs = np.arange(num)
# get the feature importance for top num and sort in reverse order
values_to_plot = feature_importances1.iloc[:num].values.ravel()[::-1]
feature_labels = list(feature_importances1.iloc[:num].index)[::-1]

plt.figure(num=None, figsize=(8, 15), dpi=80, facecolor='w', edgecolor='k');
plt.barh(ylocs, values_to_plot, align = 'center')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.title('Feature Importance Score - Random Forest')
plt.yticks(ylocs, feature_labels)
plt.show()

# %% [markdown]
# ### Using RandomizedSearchCV, Optimize Gradient Boosting Tree Classifier

# %%
# Let's create a grid over a few of these (see the scikit-learn website for the descriptions).
from sklearn.model_selection import RandomizedSearchCV

# number of trees
n_estimators = range(200,1000,200)
# maximum number of features to use at each split
max_features = ['auto','sqrt']
# maximum depth of the tree
max_depth = range(2,20,2)
# minimum number of samples to split a node
min_samples_split = range(2,10,2)
# criterion for evaluating a split
criterion = ['gini','entropy']

# random grid

random_grid = {'n_estimators':n_estimators,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_samples_split,
              'criterion':criterion}

print(random_grid)
# Out:
# {'n_estimators': range(200, 1000, 200), 'max_features': ['auto', 'sqrt'], 'max_depth': range(2, 20, 2), 'min_samples_split': range(2, 10, 2), 'criterion': ['gini', 'entropy']}

# %%
# To use the RandomizedSearchCV function, we need something to score or evaluate a set of hyperparameters. 
# Here we will use the auc.
from sklearn.metrics import make_scorer, roc_auc_score
auc_scoring = make_scorer(roc_auc_score)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc =GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
     max_depth=3, random_state=42)
gbc.fit(X_train_tf, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=1.0, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=42, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
# number of trees
n_estimators = range(50,200,50)

# maximum depth of the tree
max_depth = range(1,5,1)

# learning rate
learning_rate = [0.001,0.01,0.1]

# random grid

random_grid_gbc = {'n_estimators':n_estimators,
              'max_depth':max_depth,
              'learning_rate':learning_rate}

# create the randomized search cross-validation
gbc_random = RandomizedSearchCV(estimator = gbc, param_distributions = random_grid_gbc, n_iter = 20, cv = 2, scoring=auc_scoring,verbose = 0, random_state = 42)

import time
t1 = time.time()
gbc_random.fit(X_train_tf, y_train)
t2 = time.time()
print(t2-t1)
# Out:
# 63.014424085617065

# %%
gbc_random.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}

# %%
y_train_preds = gbc.predict_proba(X_train_tf)[:,1]
y_valid_preds = gbc.predict_proba(X_valid_tf)[:,1]

thresh = 0.5

print('Baseline gbc')
gbc_train_base_auc = roc_auc_score(y_train, y_train_preds)
gbc_valid_base_auc = roc_auc_score(y_valid, y_valid_preds)

print('Training AUC:%.3f'%(gbc_train_base_auc))
print('Validation AUC:%.3f'%(gbc_valid_base_auc))
print('Optimized gbc')
y_train_preds_random = gbc_random.best_estimator_.predict_proba(X_train_tf)[:,1]
y_valid_preds_random = gbc_random.best_estimator_.predict_proba(X_valid_tf)[:,1]
gbc_train_opt_auc = roc_auc_score(y_train, y_train_preds_random)
gbc_valid_opt_auc = roc_auc_score(y_valid, y_valid_preds_random)

print('Training AUC:%.3f'%(gbc_train_opt_auc))
print('Validation AUC:%.3f'%(gbc_valid_opt_auc))
# Out:
# Baseline gbc
# Training AUC:0.999
# Validation AUC:0.999
# Optimized gbc
# Training AUC:1.000
# Validation AUC:1.000

# %%
# You won't want to train your best classifier every time you want to run new predictions. 
# Therefore, we need to save the classifier. We will use the package pickle. 
# Pick gbc as the best classifier
pickle.dump(gbc_random.best_estimator_, open('best_classifier.pkl', 'wb'),protocol = 4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
# load the model, columns, mean values, and scaler
best_model = pickle.load(open('best_classifier.pkl','rb'))
cols_input = pickle.load(open('cols_input.sav','rb'))
df_mean_in = pd.read_csv('df_mean.csv', names =['col','mean_val'])
scaler = pickle.load(open('scaler.sav', 'rb'))

# %%
# load the data
df_train = pd.read_csv('df_train_all.csv')
df_valid= pd.read_csv('df_valid.csv')
df_test= pd.read_csv('df_test.csv')

# %%
# fill missing
df_train = fill_my_missing(df_train, df_mean_in, cols_input)
df_valid = fill_my_missing(df_valid, df_mean_in, cols_input)
df_test = fill_my_missing(df_test, df_mean_in, cols_input)

# create X and y matrices
X_train = df_train[cols_input].values
X_valid = df_valid[cols_input].values
X_test = df_test[cols_input].values

y_train = df_train['OUTPUT_LABEL'].values
y_valid = df_valid['OUTPUT_LABEL'].values
y_test = df_test['OUTPUT_LABEL'].values

# transform our data matrices 
X_train_tf = scaler.transform(X_train)
X_valid_tf = scaler.transform(X_valid)
X_test_tf = scaler.transform(X_test)
# Out:
# C:\Users\minyi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# calculate prediction probalility
y_train_preds = best_model.predict_proba(X_train_tf)[:,1]
y_valid_preds = best_model.predict_proba(X_valid_tf)[:,1]
y_test_preds = best_model.predict_proba(X_test_tf)[:,1]

# %%
# evaluate the performance
thresh = 0.38

print('Training:')
train_auc, train_accuracy, train_recall, train_precision, train_specificity = print_report(y_train,y_train_preds, thresh)
print('Validation:')
valid_auc, valid_accuracy, valid_recall, valid_precision, valid_specificity = print_report(y_valid,y_valid_preds, thresh)
print('Test:')
test_auc, test_accuracy, test_recall, test_precision, test_specificity = print_report(y_test,y_test_preds, thresh)
# Out:
# Training:
# AUC:1.000
# accuracy:0.997
# recall:1.000
# precision:0.994
# specificity:0.996
# prevalence:0.388
#
# Validation:
# AUC:1.000
# accuracy:0.997
# recall:1.000
# precision:0.994
# specificity:0.996
# prevalence:0.387
#
# Test:
# AUC:1.000
# accuracy:0.998
# recall:0.999
# precision:0.995
# specificity:0.997
# prevalence:0.389

# %%
# plot ROC curve
from sklearn.metrics import roc_curve 

fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_train_preds)
auc_train = roc_auc_score(y_train, y_train_preds)

fpr_valid, tpr_valid, thresholds_valid = roc_curve(y_valid, y_valid_preds)
auc_valid = roc_auc_score(y_valid, y_valid_preds)

fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_test_preds)
auc_test = roc_auc_score(y_test, y_test_preds)

plt.plot(fpr_train, tpr_train, 'r-',label ='Train AUC:%.3f'%auc_train)
plt.plot(fpr_valid, tpr_valid, 'b-',label ='Valid AUC:%.3f'%auc_valid)
plt.plot(fpr_test, tpr_test, 'g-',label ='Test AUC:%.3f'%auc_test)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
